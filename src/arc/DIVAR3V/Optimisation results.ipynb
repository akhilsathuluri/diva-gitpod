# %%
# ----------------------------------------------------------------
# TwoLinkRobot 
# ----------------------------------------------------------------
# Optim setting:
# LPL-GPU Server
# pop_size=70, gen=20, n=32
# algo = CMA-ES
# Weighting: 
# K_w = np.diag([1,1,1,1,100,5,5,0])

# All DVs
# {'tau_mu': 0.0053, 'b0': 1.5e-05, 'Km': 0.19, 'k_velocity': 1.06, 
# 'tau_max_m': 1.2,'omega_max_m': 4750, 'gear_ratio': 10, 'Kp': 15, 
# 'Kd': 7.745966692414834, 'm_m': 0.452}

# Assumptions
# No reachability, payload or applied force constraints on the robot
# Stiffness DVs are ignored too

# Baseline
# Kp, Kd = [15, 2*np.sqrt(15)]
# result = [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  1.90340000e+00 6.25552970e-02 2.21488702e-01 7.65725114e-08]
# best_f = [362.55]

# Optim-control
# best_x = [40.37586389, 10.79584889]
# best_f = [191.2337]
# result = [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  1.04830000e+00 6.45576134e-02 1.93361016e-01 3.36364190e-12]
# f_computed = [110.1010698392698]

# Optim-motor
# ['tau_mu', 'b0', 'Km', 'k_velocity', 'tau_max_m', 'omega_max_m', 'gear_ratio', 'Kp', 'Kd', 'm_m']
# best_x = [1.23963359e-01, 8.21454920e-03, 4.42151610e+00, 2.42814979e+01, 4.85943104e+00, 
# 5.10276159e+03, 6.10012926e+00, 8.68464895e+01, 1.71650947e+01, 1.02976934e+00]
# best_f = [88.36689]
# result = [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  6.41700000e-01 1.56310419e+00 2.66182865e+00 2.72026767e-14]
# f_computed = 88.82

# Optim-co-design
# ['tau_mu', 'b0', 'Km', 'k_velocity', 'tau_max_m', 'omega_max_m', 'gear_ratio', 'Kp', 'Kd', 'm_m', 'l1', 'l2']
# best_x = [6.17907121e-01, 1.48666641e-01, 8.79340683e-01, 1.72980544e+01,3.85429047e+00, 
# 5.52194647e+03, 2.56607694e+00, 9.39921750e+01,2.14105758e+01, 2.45136778e+00, 4.00414517e-02, 1.32539364e-01]
# best_f = [337.1515]
# result = [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  9.35200000e-01 3.77393175e+00 6.01476893e+00 6.70620616e-14]
# computed_f = 339

# Optim-co-design-heuristic
# ['omega_max_m', 'gear_ratio', 'Kp', 'Kd', 'm_m', 'l1', 'l2']
# best_x = [1.75671160e+03, 2.42603688e+01, 9.78082909e+01, 1.38293459e+01,1.29247957e+00, 
# 7.29913449e-02, 9.46402732e-02]
# best_f = [49.6723]
# result = [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  7.03500000e-01 1.91193973e-01 3.02681579e-03 7.78825409e-15]
# computed_f = 49.6740464851425
