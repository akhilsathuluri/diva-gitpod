# %%
# Imports
import numpy as np
from pydrake.all import *
from IPython.display import display, SVG, clear_output, HTML

from manipulation.meshcat_cpp_utils import(
    StartMeshcat, MeshcatJointSlidersThatPublish)
from manipulation.scenarios import AddMultibodyTriad

# Import pygmo for optimisation
import pygmo as pg
# from urdf_creator import *
from urdf_creator_struct import *
import time
from joblib import Parallel, delayed
from utils import *

# Import for structures 
import json
from operator import itemgetter
import torch

# %%
meshcat = StartMeshcat()
# Out:
# Meshcat is now available at <a href="http://localhost:7000">http://localhost:7000</a>

# %%
# Load the classifiers
clf = joblib.load('./feasibility_classifier.pkl')
# Load mean and scale data
fit_file = open('./mean_and_scale.json')
fit_params = json.load(fit_file)
fit_file.close()

# %%
# Define the number of actuators
na = 7

# GLOBAL PROBLEM SETUP

# Reference: https://wiki.ros.org/pr2_controller_manager/safety_limits
# Defining the actuator box
class ActuatorBox(LeafSystem):
    # Input values are for motor and NOT for the joint
    def __init__(self, tau_max_m, omega_max_m, gear_ratio, k_velocity):
        LeafSystem.__init__(self)
        # Both the values are motor specific and NOT joint specific
        # Get joint max torque
        self.tau_max_j = tau_max_m*gear_ratio
        self.k_vel = k_velocity
        # Convert RPM of motor to joint velocity in rad/sec
        self.omega_max_j = omega_max_m*(2*np.pi/60)/gear_ratio
        self.DeclareVectorInputPort('commanded_torque', BasicVector(na))
        self.DeclareVectorInputPort('joint_state', BasicVector(2*na))
        self.DeclareVectorOutputPort('realised_torque', BasicVector(na), self.OutputJointTorque)

    def OutputJointTorque(self, context, output):
        # Get the state values
        q = self.EvalVectorInput(context, 1).get_value()
        qvel = q[na:]
        u = self.EvalVectorInput(context, 0).get_value()
        # Compute the instantaneous torque limit
        # For the AK-70-10 motors
        kv = self.k_vel
        u_new = np.copy(u)
        # Using URDF safety controller rules
        for i in range(len(u)):
            if qvel[i]>=0 and u[i]>=0:
                u_bound = -kv*(qvel[i]-self.omega_max_j)
                u_new[i] = np.min([u[i], u_bound, self.tau_max_j])
            if qvel[i]>=0 and u[i]<=0:
                u_bound = -self.tau_max_j
                u_new[i] = np.max([u[i], u_bound])
            if qvel[i]<=0 and u[i]>=0:
                u_bound = self.tau_max_j
                u_new[i] = np.min([u[i], u_bound])
            if qvel[i]<=0 and u[i]<=0:
                u_bound = -(-kv*(np.abs(qvel[i])-self.omega_max_j))
                u_new[i] = np.max([u[i], u_bound, -self.tau_max_j])
#             print(u[i], u_bound, u_new[i])
        output.SetFromVector(u_new)

# Task definition
# Home position
q0 = np.array([-0.64, -0.35, -1.01,  1.7, -0.29 ,0.88, -0.034])
# carti = np.array([-0.1, 0.14, 0.85])
# qi = np.array([0.96, 0.44])
# q0 = qi
# cartd = np.array([-0.1, 0.32, 1.29])
# qd = np.array([-0.53, 0.58])
# qint = qd

carti = np.array([-0.53, 0.13, 0.81])
cartd = np.array([-0.23, 0.24, 1.03])

# Simulation settings
time_step = 1e-4
sim_time = 5
error_threshold = 5e-3

# Robot URDF
urdf_path = './urdfs/divar3v7308465156.urdf'
print(urdf_path)

# motor mass
m_m = 0.452
# Assumed values
tau_mu = 5.3e-3
b0 = 1.5e-5
# AK70-10 parameters
# gear ratio
gear_ratio = 10
# motor design variables
tau_max_m = 12/gear_ratio # Nm
omega_max_m = 475*gear_ratio   # RPM
Kt = 0.095        # Nm/A
Kv = 100          # RPM/V
Km = 0.19         # Nm/sqrt(W)
# Computed matrix for joule loss
K_joule = 1/np.sqrt(Km)*np.identity(na)
k_velocity = 8.33/(75*2*np.pi/60) # Nm/(rad/s)
# Control attributes
Kp = 15
Kd = 2*np.sqrt(Kp)
max_penal = 1e4

study = ["baseline_control", "baseline_motor", "baseline_codesign", "baseline_codesign_heuristics", "baseline"]

case = study[2]
if case=="baseline_control":
    # For baseline-control study
    pre_val_vals = [tau_mu, b0, Km, k_velocity, tau_max_m, omega_max_m, gear_ratio, m_m]
    pre_val_names = ["tau_mu", "b0", "Km", "k_velocity", "tau_max_m", "omega_max_m", "gear_ratio", "m_m"]
    # Define a dictionary for ease of usage and modulartiy of the dvs
    pre_val = dict(zip(pre_val_names, pre_val_vals))
    dv_names = ["Kp", "Kd"]
    print(case)
    print('pre_val: ', pre_val, 'dv_names: ', dv_names)
    sample_dv = [15, 2*np.sqrt(15)]
    print(sample_dv)
    dv_bounds = ([0,0],[100,100])
    print('dv_bounds: ', dv_bounds)
    
if case=="baseline_motor":
    # For baseline-control-motor study
    pre_val_vals = []
    pre_val_names = []
    print(case)
    # Define a dictionary for ease of usage and modulartiy of the dvs
    pre_val = dict(zip(pre_val_names, pre_val_vals))
    dv_names = ["tau_mu", "b0", "Km", "k_velocity", "tau_max_m", "omega_max_m", "gear_ratio", "Kp", "Kd", "m_m"]
    print('pre_val: ', pre_val, 'dv_names: ', dv_names)
    sample_dv = [0.0053, 1.5e-05, 0.19, 1.0606085407643906, 1.2, 4750, 10, 15, 2*np.sqrt(15), 0.452]
    print('Sample-DV: ', sample_dv)
    # Since we want to change the motor mass in the simulation here, we must include joint mass variation in the URDF
    # ['tau_mu', 'b0', 'Km', 'k_velocity', 'tau_max_m', 'omega_max_m', 'gear_ratio', 'Kp', 'Kd', 'm_m']
    dv_bounds = ([0,0,0,1e-2,1e-3,1000,0.1, 0, 0, 0],[1,1,5,1e2,5,9000,25,100,100,5])
    print('dv_bounds: ', dv_bounds)
    
if case=="baseline_codesign":
    # For baseline-codesign study
    pre_val_vals = []
    pre_val_names = []
    print(case)
    # Define a dictionary for ease of usage and modulartiy of the dvs
    pre_val = dict(zip(pre_val_names, pre_val_vals))
    dv_names = ["tau_mu", "b0", "Km", "k_velocity", "tau_max_m", "omega_max_m", "gear_ratio", "Kp", "Kd", "m_m", "a1", "lua","a23_distr", "lfa", "a45_distr", "a7","k1","k2","k3"]
    task_info = {'carti': carti, 'cartd': cartd}
    pre_val.update(task_info)
    print('pre_val: ', pre_val, 'dv_names: ', dv_names)
    sample_dv = [0.0053, 1.5e-05, 0.19, 1.0606085407643906, 1.2, 4750, 10, 15, 2*np.sqrt(15), 0.452, 0.36, 0.36, 0.5, 0.36, 0.5, 0.36,646.2338,69400000,56100000]
    print('Sample-DV: ', sample_dv)
    # Since we want to change the motor mass in the simulation here, we must include joint mass variation in the URDF
    # ['tau_mu', 'b0', 'Km', 'k_velocity', 'tau_max_m', 'omega_max_m', 'gear_ratio', 'Kp', 'Kd', 'm_m']
    dv_bounds = ([0,0,1e-3,1e-2,1e-3,1000,0.1, 1e-4, 1e-4, 1e-3,0.1,0.1,0.05,0.1,0.05,0.1,100,100,100],[1e-2,1e-2,5,25,3,9000,25,100,100,2,0.3,0.5,0.95,0.5,0.95,0.25,30900,379000000,379000000])
    print('dv_bounds: ', dv_bounds)
#     {'tau_mu': 0.0053, 'b0': 1.5e-05, 'Km': 0.19, 'k_velocity': 1.0606085407643906, 'tau_max_m': 1.2, 'omega_max_m': 4750, 'gear_ratio': 10, 'Kp': 15, 'Kd': 7.745966692414834, 'm_m': 0.452, 'a1': 0.36, 'lua': 0.36, 'a23_distr': 0.5, 'lfa': 0.36, 'a45_distr': 0.5, 'a7': 0.36, 'k1': 646.2338, 'k2': 69400000, 'k3': 56100000}


    # Limited heuristics available from the paper
if case=="baseline_codesign_heuristics":
    # For baseline-codesign study
    pre_val_names = ["tau_mu", "b0", "k_velocity"]
    pre_val_vals = [0.0053, 1.5e-05, 1.0606085407643906]
    print(case)
    # Define a dictionary for ease of usage and modulartiy of the dvs
    pre_val = dict(zip(pre_val_names, pre_val_vals))
    dv_names = ["omega_max_m", "gear_ratio", "Kp", "Kd", "m_m", "l1", "l2"]
    print('pre_val: ', pre_val, 'dv_names: ', dv_names)
    sample_dv = [4750, 10, 15, 2*np.sqrt(15), 0.452, 0.36, 0.36]
    print('Sample-DV: ', sample_dv)
    # Since we want to change the motor mass in the simulation here, we must include joint mass variation in the URDF
    # ['tau_mu', 'b0', 'Km', 'k_velocity', 'tau_max_m', 'omega_max_m', 'gear_ratio', 'Kp', 'Kd', 'm_m']
    dv_bounds = ([1000,0.1, 0, 0, 1e-3,1e-2,1e-2],[9000,25,100,100,5,2,2])
    print('dv_bounds: ', dv_bounds)  
    
if case=="baseline":
    print(case)
    # For simulation study
    pre_val_vals = [tau_mu, b0, Km, k_velocity, tau_max_m, omega_max_m, gear_ratio, Kp, Kd, m_m]
    pre_val_names = ["tau_mu", "b0", "Km", "k_velocity", "tau_max_m", "omega_max_m", "gear_ratio", "Kp", "Kd", "m_m"]
    # Define a dictionary for ease of usage and modulartiy of the dvs
    pre_val = dict(zip(pre_val_names, pre_val_vals))
    dv_names = []
    sample_dv = []
    task_info = {'carti': carti, 'cartd': cartd}
    pre_val.update(task_info)
    print(pre_val)
# Out:
# ./urdfs/divar3v7308465156.urdf
# baseline_codesign
# pre_val:  {'carti': array([-0.53,  0.13,  0.81]), 'cartd': array([-0.23,  0.24,  1.03])} dv_names:  ['tau_mu', 'b0', 'Km', 'k_velocity', 'tau_max_m', 'omega_max_m', 'gear_ratio', 'Kp', 'Kd', 'm_m', 'a1', 'lua', 'a23_distr', 'lfa', 'a45_distr', 'a7', 'k1', 'k2', 'k3']
# Sample-DV:  [0.0053, 1.5e-05, 0.19, 1.0606085407643906, 1.2, 4750, 10, 15, 7.745966692414834, 0.452, 0.36, 0.36, 0.5, 0.36, 0.5, 0.36, 646.2338, 69400000, 56100000]
# dv_bounds:  ([0, 0, 0.001, 0.01, 0.001, 1000, 0.1, 0.0001, 0.0001, 0.001, 0.1, 0.1, 0.05, 0.1, 0.05, 0.1, 100, 100, 100], [0.01, 0.01, 5, 25, 3, 9000, 25, 100, 100, 2, 0.3, 0.5, 0.95, 0.5, 0.95, 0.25, 30900, 379000000, 379000000])

# %%
# ADD INDIVIDUAL STIFFNESSES TO ALL THE LINKS

link_lengths = np.array([0.3,0.25,0.25,0.2,0.3,0.25])
kvals = np.array([0,0,0])
input_list = np.c_[np.array([kvals,]*6), link_lengths*1000]
input_list_torch = torch.from_numpy(input_list)
feas_mean = np.array(fit_params['feas_data']['mean'])
feas_scale = np.array(fit_params['feas_data']['scale'])
norm_input_list = (input_list_torch-feas_mean)/feas_scale
pred_feas = clf.predict(norm_input_list.cpu().numpy())

# %%
clf.predict(norm_input_list.cpu().numpy())
# Out:
# array([1., 1., 1., 1., 1., 1.])

# %%
pred_feas
# Out:
# array([1., 1., 1., 1., 1., 1.])

# %%
def compute_QoI(pre_val, dv_names, sample_dv, case, clf, fit_params, run_sim=False):
    # Construct the master dv list
    dv_dict = dict(zip(dv_names, sample_dv))
    if case==study[3]:
        # Map the entire design space from the sampled DVs using heuristics
        # Current heuristics used are from the jump paper
        dv_dict['tau_max_m'] = 5.48*dv_dict['m_m']**0.97
        dv_dict['Km'] = 0.15*dv_dict['m_m']**1.39
        # Later also fit k_velocity values
    dv = {**pre_val, **dv_dict}
    # Construct a new URDF if its such a case
#     print(case)
    if (case==study[1]) or (case==study[2]) or (case==study[3]):
        urdf_path, updated_dv =urdf_creator(dv, fit_params)
        dv = updated_dv
    else:
        urdf_path = './urdfs/divar3v7308465156.urdf'
    # Construct the sim diagram
    builder = DiagramBuilder()
    plant, scene_graph = AddMultibodyPlantSceneGraph(builder, time_step=time_step)
    print(urdf_path)
    model = Parser(plant, scene_graph).AddModelFromFile(urdf_path, 'diva_robot')
    X_R = RigidTransform(RotationMatrix.MakeYRotation(-np.pi/2), np.array([-0.1, 0.5, 1.2]))
    plant.WeldFrames(plant.world_frame(), plant.get_body(plant.GetBodyIndices(model)[0]).body_frame(), X_R)
    if run_sim:
#         print(urdf_path)
        meshcat.Delete()
        meshcat.DeleteAddedControls()
        # Spawn table
        table = Parser(plant, scene_graph).AddModelFromFile('./urdfs/table/extra_heavy_duty_table_modified.sdf','table')

    # Due to the way the problem is formulated, spheres and the table can be safely ignored
    plant.Finalize()
    actuator = builder.AddSystem(ActuatorBox(dv['tau_max_m'], dv['omega_max_m'], dv['gear_ratio'], dv['k_velocity']))
    
    if run_sim:
        visualizer = MeshcatVisualizerCpp.AddToBuilder(builder, scene_graph, meshcat)
    
    # Initialise controller params, for now limited to Kp and Kd search
    Kp = np.full(na, dv['Kp'])
    Ki = np.full(na, 0)
    Kd = np.full(na, dv['Kd'])
    
    iiwa_controller = builder.AddSystem(InverseDynamicsController(plant, Kp, Ki, Kd, False))
    iiwa_controller.set_name("iiwa_controller");
    # Complete connections
    builder.Connect(plant.get_state_output_port(model),
                iiwa_controller.get_input_port_estimated_state())
    builder.Connect(iiwa_controller.get_output_port_control(), 
                actuator.get_input_port(0))
    builder.Connect(plant.get_state_output_port(model),
                actuator.get_input_port(1))
    builder.Connect(actuator.get_output_port(), plant.get_actuation_input_port())
    
    # Connecting a data logger
    # Commanded torque
    logger1 = LogVectorOutput(iiwa_controller.get_output_port_control(), builder)
    # Joint state
    logger2 = LogVectorOutput(plant.get_state_output_port(model), builder)
    # Realised torque
    logger3 = LogVectorOutput(actuator.get_output_port(), builder)

    diagram = builder.Build()
    context = diagram.CreateDefaultContext()
    plant_context = plant.GetMyMutableContextFromRoot(context)
    gripper_frame = plant.GetBodyByName("eef").body_frame()
    
    # Feasibility check
    link_lengths = np.array(itemgetter('a1', 'a2', 'a3', 'a4', 'a5', 'a7')(dv))
    kvals = itemgetter('k1', 'k2', 'k3')(dv)
    input_list = np.c_[np.array([kvals,]*6), link_lengths*1000]
    input_list_torch = torch.from_numpy(input_list)
    feas_mean = np.array(fit_params['feas_data']['mean'])
    feas_scale = np.array(fit_params['feas_data']['scale'])
    norm_input_list = (input_list_torch-feas_mean)/feas_scale
    pred_feas = clf.predict(norm_input_list.cpu().numpy())
    if pred_feas.all():
        feasibility = 0

        # DEFLECTION
        lx = input_list[:,-1]
        ncomp = len(input_list)
        Kc = np.empty([input_list.shape[1],input_list.shape[1],input_list.shape[0]])
        for n in range(ncomp):
            K_cs1_1 = input_list[n][0]
            K_cs2_2 = input_list[n][1]
            K_cs4_4 = input_list[n][2]

            Kc[:,:,n] = np.array([[K_cs1_1,(K_cs1_1*lx[n]**2 + K_cs2_2 - K_cs4_4)/(2*lx[n]),-K_cs1_1,(K_cs1_1*lx[n]**2 - K_cs2_2 + K_cs4_4)/(2*lx[n])],
            [(K_cs1_1*lx[n]**2 + K_cs2_2 - K_cs4_4)/(2*lx[n]),K_cs2_2, -(K_cs1_1*lx[n]**2 + K_cs2_2 - K_cs4_4)/(2*lx[n]),   (K_cs1_1*lx[n]**2)/2 - K_cs2_2/2 - K_cs4_4/2],
            [-K_cs1_1, -(K_cs1_1*lx[n]**2 + K_cs2_2 - K_cs4_4)/(2*lx[n]),K_cs1_1, -(K_cs1_1*lx[n]**2 - K_cs2_2 + K_cs4_4)/(2*lx[n])],
            [(K_cs1_1*lx[n]**2 - K_cs2_2 + K_cs4_4)/(2*lx[n]),(K_cs1_1*lx[n]**2)/2 - K_cs2_2/2 - K_cs4_4/2, -(K_cs1_1*lx[n]**2 - K_cs2_2 + K_cs4_4)/(2*lx[n]),K_cs4_4]])

        # Initialising global variables
        Kg = np.zeros([(ncomp+1)*2,(ncomp+1)*2])
        Dg = np.zeros([(ncomp+1)*2,1])
        Fg = np.zeros([(ncomp+1)*2,1])
        # Constructing the global stiffness matrix
        for elx in range(ncomp):
            n1 = 2*elx
            n2 = 2*(elx+1)
            Kg[n1:n2+2, n1:n2+2] += Kc[:,:,elx]
        # Computing the displacements given the loading
        Fg[ncomp*2] = 10
        Dg = np.linalg.inv(Kg[2:,2:])@Fg[2:]
        deflection = np.max(np.abs(Dg))

    else:
        feasibility = max_penal
        deflection = max_penal
    
    # Now computing the QoIs
    # WORKSPACE
    # Workspace is always satisfied since its the same robot
    # Compute IK - pos1
    ik = InverseKinematics(plant, plant_context)
    ik.AddPositionConstraint(
                gripper_frame, [0, 0, 0], plant.world_frame(),
                dv['carti'], dv['carti'])
    # Adding the orientation constraint to keep the end-effector
    # perpendicular to the table
    ik.AddOrientationConstraint(gripper_frame, 
                                RotationMatrix(), 
                                plant.world_frame(),
                               RollPitchYaw([-3.14, 0, 0]).ToRotationMatrix(), 0.0)
    
    prog = ik.get_mutable_prog()
    q = ik.q()
    prog.AddQuadraticErrorCost(np.identity(len(q)), q0, q)
    prog.SetInitialGuess(q, q0)
    result = Solve(ik.prog())
    qi = result.GetSolution(ik.q())
    qi = (np.arctan2(np.sin(qi), np.cos(qi)))
    plant.SetPositions(plant.GetMyContextFromRoot(context),model,qi)
    eef_pos_realised = plant.GetBodyByName('eef').EvalPoseInWorld(plant_context).translation()
    w1 = np.linalg.norm(eef_pos_realised-dv['carti'])
    
    # Compute IK - pos2
    ik = InverseKinematics(plant, plant_context)
    ik.AddPositionConstraint(
                gripper_frame, [0, 0, 0], plant.world_frame(),
                dv['cartd'], dv['cartd'])
    ik.AddOrientationConstraint(gripper_frame, 
                                RotationMatrix(), 
                                plant.world_frame(),
                               RollPitchYaw([-3.14, 0, 0]).ToRotationMatrix(), 0.0)
    prog = ik.get_mutable_prog()
    q = ik.q()
    prog.AddQuadraticErrorCost(np.identity(len(q)), qi, q)
    prog.SetInitialGuess(q, qi)
    result = Solve(ik.prog())
    qd = result.GetSolution(ik.q())
    qd = (np.arctan2(np.sin(qd), np.cos(qd)))
    plant.SetPositions(plant.GetMyContextFromRoot(context),model,qd)
    eef_pos_realised = plant.GetBodyByName('eef').EvalPoseInWorld(plant_context).translation()
    w2 = np.linalg.norm(eef_pos_realised-dv['cartd'])
    # Compute the error in positions    
    workspace = w1+w2
    # APPLIED FORCE
    # Applied force will also remain the same given that the tau_max is fixed
    applied_force = 0
    # PAYLOAD
    # same as applied force
    payload = 0
    # Setup the simulation
    xd = np.hstack((qd, 0*qd))
    plant.SetPositions(plant_context, qi)
    iiwa_controller.GetInputPort('desired_state').FixValue(
    iiwa_controller.GetMyMutableContextFromRoot(context), xd);
    # Simulation
    simulator = Simulator(diagram, context)
    simulator.AdvanceTo(sim_time);
    
    # Now we want to get the simulation data, i.e., 
    # the torque applied, final time of the joint variables
    log1 = logger1.FindLog(context)
    log2 = logger2.FindLog(context)
    log3 = logger3.FindLog(context)
    
    error = np.abs(log2.data()[:na,:].transpose() - np.tile(qd,(log3.data().shape[1],1)))
    e_norm = np.array([np.linalg.norm(val) for val in error])
    for i in range(len(e_norm)):
        if np.all(e_norm[i:]<error_threshold):
            break
    final_error = e_norm[-1]
    # CYCLE TIME
    ts = log2.sample_times()[i]
    
    omega_j = []
    for i in range(log2.data().shape[1]):
        omega_j.append(log2.data()[:,i][na:])
    omega_j = np.array(omega_j).transpose()
    omega_m = omega_j*dv['gear_ratio']
    # Convert the motor speed to RPM
    omega_m_rpm = omega_m*60/(2*np.pi)
    # Motor torque realised
    tau_m = log3.data()/dv['gear_ratio']
    
    K_joule = 1/np.sqrt(dv['Km'])*np.identity(na)
    # Total power losses
    inst_friction_power = []
    inst_joule_power = []
    for i in range(len(log3.sample_times())):
        omega_inst = omega_m[:, i]
        tau_f = dv['tau_mu']*np.sign(omega_inst)+dv['b0']*omega_inst
        P_f = np.dot(tau_f, omega_inst)
        inst_friction_power.append(P_f)
        tau_t = tau_f+tau_m[:, i]
        P_t = np.dot(K_joule.dot(tau_t), tau_t)
        inst_joule_power.append(P_t)
    
    # POWER LOSSES
    total_friction_loss = np.sum(inst_friction_power)*time_step
    total_joule_loss = np.sum(inst_joule_power)*time_step
    
    results = np.array([workspace, feasibility, deflection, payload, ts, total_friction_loss, total_joule_loss, final_error])
#     print(results)
    
    if run_sim:
        # Angular angular velocity of the motors in RPM
        motor_rpm = omega_j*gear_ratio*60/(2*np.pi)
        plt.plot(log2.sample_times(), motor_rpm[0, :], log2.sample_times(), motor_rpm[1, :])
        plt.title('motor RPM vs time')

        # Motor torque demanded
        fig = plt.figure()
        plt.plot(log1.sample_times(), log1.data()[0, :], log1.sample_times(), log1.data()[1, :])
        plt.title("motor torque demanded vs time")

        # Motor torque demanded
        fig = plt.figure()
        plt.plot(log1.sample_times(), log3.data()[0, :], log1.sample_times(), log3.data()[1, :])
        plt.title("motor torque realised vs time")

        print('Max realised torque', np.max(np.abs(log3.data())))

    return results

# %%
# sample_dv = {'tau_mu': 0.0053, 'b0': 1.5e-05, 'Km': 0.19, 'k_velocity': 1.0606085407643906, 'tau_max_m': 1.2, 'omega_max_m': 4750, 'gear_ratio': 10, 'Kp': 15, 'Kd': 7.745966692414834, 'm_m': 0.452, 'a1': 0.36, 'lua': 0.36, 'a23_distr': 0.5, 'lfa': 0.36, 'a45_distr': 0.5, 'a7': 0.36, 'k1': 646.2338, 'k2': 69400000, 'k3': 56100000}
# urdf_creator(sample_dv, fit_params)
dv_names
# Out:
# ['tau_mu',
#  'b0',
#  'Km',
#  'k_velocity',
#  'tau_max_m',
#  'omega_max_m',
#  'gear_ratio',
#  'Kp',
#  'Kd',
#  'm_m',
#  'a1',
#  'lua',
#  'a23_distr',
#  'lfa',
#  'a45_distr',
#  'a7',
#  'k1',
#  'k2',
#  'k3']

# %%
# test with a sample or for sim
sample_dv_2 = [0, 0, 3.35, 0.01, 1, 1000, 1, 100, 18.86, 1.07, 0.1, 0.5, 0.486, 0.5, 0.95, 0.25,30900, 100, 379000000]
# print(sample_dv_2)
compute_QoI(pre_val, dv_names, sample_dv_2, case, clf, fit_params, run_sim=True)
# Out:
# ./urdfs/AutoGen/divar3v8684258059.urdf
# Max realised torque 1.0
# array([1.26221545e-10, 1.00000000e+04, 1.00000000e+04, 0.00000000e+00,
#        5.00000000e+00, 0.00000000e+00, 1.82181608e+01, 1.94980698e+01])

# %%
# Setting up a problem
class Baseline_Problem:
    def __init__(self, pre_val, dv_names, dv_bounds, case, clf, fit_params):
        self.pre_val = pre_val
        self.dv_names = dv_names
        self.dv_bounds = dv_bounds
        self.case = case
        self.clf = clf
        self.fit_params = fit_params
        pass

    def fitness(self,sample_dv):
        # print(sample_dv)
        # Write a function to output the QoI values
        results = compute_QoI(self.pre_val, self.dv_names, sample_dv, self.case, self.clf, self.fit_params)
        # Add weighting factor, K_w
        # workspace, feasibility, deflection, payload, ts, total_friction_loss, total_joule_loss, final_error
        K_w = np.diag([1,1,10,1,100,5,5,0])
        # Quadratic objective meta function with weights
        fitness_val = np.matmul(K_w, results).dot(results)
        return [fitness_val]

    def get_bounds(self):
        # Define bounds on the controller variables
        # Ideally from a csv file like before so that one can easily extend the optimisation problem
        return self.dv_bounds

    def get_name(self):
        # get the name of the problem also from the csv sheet
        return "Baseline_Codesign"

# %%
# Using CMA-ES
prob = pg.problem(Baseline_Problem(pre_val, dv_names, dv_bounds, case, clf, fit_params))
algo = pg.algorithm(pg.cmaes(gen = 3, sigma0=0.3, force_bounds=True))
algo.set_verbosity(100)

# Writing a custom island to see if we can make it work
# The default mp_island fails because of the pickle error from PyCapsule
# caused by drake AddMultibodyPlantSceneGraph function
class cool_isl:
    def run_evolve(self, algo, pop):
        # Island serially runs to evolve the pop
        new_pop = algo.evolve(pop)
        return algo, new_pop
    def get_name(self):
        return "This is a cool island that works"

# %%
# %%time
# Atleast we have a bfe to spawn the initial pop
# Since the evolve method is the core for optimisation there 
# is nothing I can do to parallelise that part
# archi = pg.archipelago(n=1, algo = algo, prob=prob, pop_size=30, b = pg.default_bfe(), udi = cool_isl())
archi = pg.archipelago(n=1, algo = algo, prob=prob, pop_size=300, udi = cool_isl())
archi.evolve();
archi.wait_check()
# Out:
# ./urdfs/AutoGen/divar3v5263311697.urdf
# ./urdfs/AutoGen/divar3v2148105361.urdf
# ./urdfs/AutoGen/divar3v3751894665.urdf
# ./urdfs/AutoGen/divar3v5482944558.urdf
# ./urdfs/AutoGen/divar3v7667619568.urdf
# ./urdfs/AutoGen/divar3v8369628978.urdf
# ./urdfs/AutoGen/divar3v8779767798.urdf
# ./urdfs/AutoGen/divar3v668637983.urdf
# ./urdfs/AutoGen/divar3v8729524354.urdf
# ./urdfs/AutoGen/divar3v8855219608.urdf
# ./urdfs/AutoGen/divar3v3433454978.urdf
# ./urdfs/AutoGen/divar3v4564117886.urdf
# ./urdfs/AutoGen/divar3v2497309560.urdf
# ./urdfs/AutoGen/divar3v5871927027.urdf
# ./urdfs/AutoGen/divar3v4472323158.urdf
# ./urdfs/AutoGen/divar3v9239652383.urdf
# ./urdfs/AutoGen/divar3v1851360093.urdf
# ./urdfs/AutoGen/divar3v9046580979.urdf
# ./urdfs/AutoGen/divar3v5539306585.urdf
# ./urdfs/AutoGen/divar3v7018810232.urdf
# ./urdfs/AutoGen/divar3v5311460278.urdf
# ./urdfs/AutoGen/divar3v4242396375.urdf
# ./urdfs/AutoGen/divar3v4072025958.urdf
# ./urdfs/AutoGen/divar3v8586923776.urdf
# ./urdfs/AutoGen/divar3v7872287487.urdf
# ./urdfs/AutoGen/divar3v1234736532.urdf
# ./urdfs/AutoGen/divar3v9314460504.urdf
# ./urdfs/AutoGen/divar3v7044716804.urdf
# ./urdfs/AutoGen/divar3v3095674007.urdf
# ./urdfs/AutoGen/divar3v8745545831.urdf
# ./urdfs/AutoGen/divar3v3465826969.urdf
# ./urdfs/AutoGen/divar3v1342582334.urdf
# ./urdfs/AutoGen/divar3v6286137072.urdf
# ./urdfs/AutoGen/divar3v1583287952.urdf
# ./urdfs/AutoGen/divar3v8418322493.urdf
# ./urdfs/AutoGen/divar3v6526897299.urdf
# ./urdfs/AutoGen/divar3v19572824.urdf
# ./urdfs/AutoGen/divar3v252372362.urdf
# ./urdfs/AutoGen/divar3v5413068464.urdf
# ./urdfs/AutoGen/divar3v2268465412.urdf
# ./urdfs/AutoGen/divar3v571304897.urdf
# ./urdfs/AutoGen/divar3v9850188131.urdf
# ./urdfs/AutoGen/divar3v915563753.urdf
# ./urdfs/AutoGen/divar3v2829679280.urdf
# ./urdfs/AutoGen/divar3v4760441057.urdf
# ./urdfs/AutoGen/divar3v4236253471.urdf
# ./urdfs/AutoGen/divar3v2011058375.urdf
# ./urdfs/AutoGen/divar3v984143158.urdf
# ./urdfs/AutoGen/divar3v5496414556.urdf
# ./urdfs/AutoGen/divar3v5576438543.urdf
# ./urdfs/AutoGen/divar3v3993517853.urdf
# ./urdfs/AutoGen/divar3v6152711748.urdf
# ./urdfs/AutoGen/divar3v7226270838.urdf
# ./urdfs/AutoGen/divar3v1107855763.urdf
# ./urdfs/AutoGen/divar3v7261642219.urdf
# ./urdfs/AutoGen/divar3v4865452474.urdf
# ./urdfs/AutoGen/divar3v8218282548.urdf
# ./urdfs/AutoGen/divar3v7394202566.urdf
# ./urdfs/AutoGen/divar3v2085232296.urdf
# ./urdfs/AutoGen/divar3v5108698546.urdf
# ./urdfs/AutoGen/divar3v1362709381.urdf
# ./urdfs/AutoGen/divar3v7428686941.urdf
# ./urdfs/AutoGen/divar3v3105048780.urdf
# ./urdfs/AutoGen/divar3v4397807774.urdf
# ./urdfs/AutoGen/divar3v6249215462.urdf
# ./urdfs/AutoGen/divar3v9646151771.urdf
# ./urdfs/AutoGen/divar3v9303534903.urdf
# ./urdfs/AutoGen/divar3v9965432405.urdf
# ./urdfs/AutoGen/divar3v3832179451.urdf
# ./urdfs/AutoGen/divar3v9518649034.urdf
# ./urdfs/AutoGen/divar3v6569801905.urdf
# ./urdfs/AutoGen/divar3v6627964328.urdf
# ./urdfs/AutoGen/divar3v3885153929.urdf
# ./urdfs/AutoGen/divar3v8931016944.urdf
# ./urdfs/AutoGen/divar3v8941997476.urdf
# ./urdfs/AutoGen/divar3v6060825929.urdf
# ./urdfs/AutoGen/divar3v4473135752.urdf
# ./urdfs/AutoGen/divar3v5916917847.urdf
# ./urdfs/AutoGen/divar3v9407942481.urdf
# ./urdfs/AutoGen/divar3v2151377432.urdf
# ./urdfs/AutoGen/divar3v6011024897.urdf
# ./urdfs/AutoGen/divar3v926777628.urdf
# ./urdfs/AutoGen/divar3v8651833779.urdf
# ./urdfs/AutoGen/divar3v5247580013.urdf
# ./urdfs/AutoGen/divar3v7912937005.urdf
# ./urdfs/AutoGen/divar3v4131847574.urdf
# ./urdfs/AutoGen/divar3v5815390668.urdf
# ./urdfs/AutoGen/divar3v1108599429.urdf
# ./urdfs/AutoGen/divar3v4208243710.urdf
# ./urdfs/AutoGen/divar3v1075375520.urdf
# ./urdfs/AutoGen/divar3v3630727000.urdf
# ./urdfs/AutoGen/divar3v7739968685.urdf
# ./urdfs/AutoGen/divar3v7584577662.urdf
# ./urdfs/AutoGen/divar3v3939002096.urdf
# ./urdfs/AutoGen/divar3v5130087825.urdf
# ./urdfs/AutoGen/divar3v7454361623.urdf
# ./urdfs/AutoGen/divar3v7454841323.urdf
# ./urdfs/AutoGen/divar3v9702459765.urdf
# ./urdfs/AutoGen/divar3v1360909073.urdf
# ./urdfs/AutoGen/divar3v4271993480.urdf
# ./urdfs/AutoGen/divar3v8049448514.urdf
# ./urdfs/AutoGen/divar3v358814870.urdf
# ./urdfs/AutoGen/divar3v4098710040.urdf
# ./urdfs/AutoGen/divar3v795630024.urdf
# ./urdfs/AutoGen/divar3v9697506771.urdf
# ./urdfs/AutoGen/divar3v3066243776.urdf
# ./urdfs/AutoGen/divar3v2197986585.urdf
# ./urdfs/AutoGen/divar3v8421440745.urdf
# ./urdfs/AutoGen/divar3v1154155948.urdf
# ./urdfs/AutoGen/divar3v100506142.urdf
# ./urdfs/AutoGen/divar3v6687844533.urdf
# ./urdfs/AutoGen/divar3v3509628704.urdf
# ./urdfs/AutoGen/divar3v8827417223.urdf
# ./urdfs/AutoGen/divar3v8422142225.urdf
# ./urdfs/AutoGen/divar3v1636557000.urdf
# ./urdfs/AutoGen/divar3v319538398.urdf
# ./urdfs/AutoGen/divar3v7356878922.urdf
# ./urdfs/AutoGen/divar3v5975893231.urdf
# ./urdfs/AutoGen/divar3v7714999115.urdf
# ./urdfs/AutoGen/divar3v3743749884.urdf
# ./urdfs/AutoGen/divar3v9832403201.urdf
# ./urdfs/AutoGen/divar3v2031005330.urdf
# ./urdfs/AutoGen/divar3v9244477092.urdf
# ./urdfs/AutoGen/divar3v3687667948.urdf
# ./urdfs/AutoGen/divar3v4173642412.urdf
# ./urdfs/AutoGen/divar3v1438264417.urdf
# ./urdfs/AutoGen/divar3v1908887848.urdf
# ./urdfs/AutoGen/divar3v5958455216.urdf
# ./urdfs/AutoGen/divar3v2867135841.urdf
# ./urdfs/AutoGen/divar3v9856208675.urdf
# ./urdfs/AutoGen/divar3v3958405798.urdf
# ./urdfs/AutoGen/divar3v2250346891.urdf
# ./urdfs/AutoGen/divar3v7917095862.urdf
# ./urdfs/AutoGen/divar3v67284232.urdf
# ./urdfs/AutoGen/divar3v6756714884.urdf
# ./urdfs/AutoGen/divar3v8313735466.urdf
# ./urdfs/AutoGen/divar3v1635598164.urdf
# ./urdfs/AutoGen/divar3v7594854526.urdf
# ./urdfs/AutoGen/divar3v1858011789.urdf
# ./urdfs/AutoGen/divar3v7781176416.urdf
# ./urdfs/AutoGen/divar3v4685403918.urdf
# ./urdfs/AutoGen/divar3v5357133163.urdf
# ./urdfs/AutoGen/divar3v8051305022.urdf
# ./urdfs/AutoGen/divar3v5746351599.urdf
# ./urdfs/AutoGen/divar3v3254278584.urdf
# ./urdfs/AutoGen/divar3v1645907536.urdf
# ./urdfs/AutoGen/divar3v2376766809.urdf
# ./urdfs/AutoGen/divar3v4920834444.urdf
# ./urdfs/AutoGen/divar3v7053441849.urdf
# ./urdfs/AutoGen/divar3v1631002397.urdf
# ./urdfs/AutoGen/divar3v9250423625.urdf
# ./urdfs/AutoGen/divar3v5305404366.urdf
# ./urdfs/AutoGen/divar3v5575278139.urdf
# ./urdfs/AutoGen/divar3v4332526943.urdf
# ./urdfs/AutoGen/divar3v3153827424.urdf
# ./urdfs/AutoGen/divar3v3952340924.urdf
# ./urdfs/AutoGen/divar3v3064556360.urdf
# ./urdfs/AutoGen/divar3v8311351092.urdf
# ./urdfs/AutoGen/divar3v9410870651.urdf
# ./urdfs/AutoGen/divar3v8020074182.urdf
# ./urdfs/AutoGen/divar3v9354660823.urdf
# ./urdfs/AutoGen/divar3v3069615628.urdf
# ./urdfs/AutoGen/divar3v5635728458.urdf
# ./urdfs/AutoGen/divar3v3526751482.urdf
# ./urdfs/AutoGen/divar3v1036688839.urdf
# ./urdfs/AutoGen/divar3v6729125488.urdf
# ./urdfs/AutoGen/divar3v9219031798.urdf
# ./urdfs/AutoGen/divar3v1189872714.urdf
# ./urdfs/AutoGen/divar3v5753486637.urdf
# ./urdfs/AutoGen/divar3v5963500479.urdf
# ./urdfs/AutoGen/divar3v5441088783.urdf
# ./urdfs/AutoGen/divar3v5351895000.urdf
# ./urdfs/AutoGen/divar3v2050625213.urdf
# ./urdfs/AutoGen/divar3v9401105541.urdf
# ./urdfs/AutoGen/divar3v287615030.urdf
# ./urdfs/AutoGen/divar3v3893453033.urdf
# ./urdfs/AutoGen/divar3v5426002240.urdf
# ./urdfs/AutoGen/divar3v4038030921.urdf
# ./urdfs/AutoGen/divar3v5687457079.urdf
# ./urdfs/AutoGen/divar3v409627570.urdf
# ./urdfs/AutoGen/divar3v9402112618.urdf
# ./urdfs/AutoGen/divar3v1216619965.urdf
# ./urdfs/AutoGen/divar3v6887200773.urdf
# ./urdfs/AutoGen/divar3v3123211915.urdf
# ./urdfs/AutoGen/divar3v6995772939.urdf
# ./urdfs/AutoGen/divar3v7893095057.urdf
# ./urdfs/AutoGen/divar3v9399355653.urdf
# ./urdfs/AutoGen/divar3v6980852982.urdf
# ./urdfs/AutoGen/divar3v163278615.urdf
# ./urdfs/AutoGen/divar3v693182611.urdf
# ./urdfs/AutoGen/divar3v8533585737.urdf
# ./urdfs/AutoGen/divar3v865906827.urdf
# ./urdfs/AutoGen/divar3v1897585813.urdf
# ./urdfs/AutoGen/divar3v4520796901.urdf
# ./urdfs/AutoGen/divar3v9699861770.urdf
# ./urdfs/AutoGen/divar3v4008909719.urdf
# ./urdfs/AutoGen/divar3v4510416365.urdf
# ./urdfs/AutoGen/divar3v8131895114.urdf
# ./urdfs/AutoGen/divar3v3262322518.urdf
# ./urdfs/AutoGen/divar3v7636835346.urdf
# ./urdfs/AutoGen/divar3v3543170680.urdf
# ./urdfs/AutoGen/divar3v3983431432.urdf
# ./urdfs/AutoGen/divar3v2428131075.urdf
# ./urdfs/AutoGen/divar3v5002390405.urdf
# ./urdfs/AutoGen/divar3v2332085613.urdf
# ./urdfs/AutoGen/divar3v5753704224.urdf
# ./urdfs/AutoGen/divar3v9370755613.urdf
# ./urdfs/AutoGen/divar3v192676204.urdf
# ./urdfs/AutoGen/divar3v3436935243.urdf
# ./urdfs/AutoGen/divar3v4285939452.urdf
# ./urdfs/AutoGen/divar3v9488531438.urdf
# ./urdfs/AutoGen/divar3v7276740251.urdf
# ./urdfs/AutoGen/divar3v5079515370.urdf
# ./urdfs/AutoGen/divar3v3741067679.urdf
# ./urdfs/AutoGen/divar3v6651981331.urdf
# ./urdfs/AutoGen/divar3v967169090.urdf
# ./urdfs/AutoGen/divar3v4954010162.urdf
# ./urdfs/AutoGen/divar3v8814091615.urdf
# ./urdfs/AutoGen/divar3v6999423534.urdf
# ./urdfs/AutoGen/divar3v4490343747.urdf
# ./urdfs/AutoGen/divar3v5171564409.urdf
# ./urdfs/AutoGen/divar3v7638853052.urdf
# ./urdfs/AutoGen/divar3v4823530755.urdf
# ./urdfs/AutoGen/divar3v4115704269.urdf
# ./urdfs/AutoGen/divar3v1922313146.urdf
# ./urdfs/AutoGen/divar3v3001625212.urdf
# ./urdfs/AutoGen/divar3v6029947219.urdf
# ./urdfs/AutoGen/divar3v2449106914.urdf
# ./urdfs/AutoGen/divar3v2732154629.urdf
# ./urdfs/AutoGen/divar3v6127514415.urdf
# ./urdfs/AutoGen/divar3v7954658624.urdf
# ./urdfs/AutoGen/divar3v3491069055.urdf
# ./urdfs/AutoGen/divar3v2479534308.urdf
# ./urdfs/AutoGen/divar3v3672600822.urdf
# ./urdfs/AutoGen/divar3v359956982.urdf
# ./urdfs/AutoGen/divar3v182481226.urdf
# ./urdfs/AutoGen/divar3v2880000876.urdf
# ./urdfs/AutoGen/divar3v9450933508.urdf
# ./urdfs/AutoGen/divar3v6104687531.urdf
# ./urdfs/AutoGen/divar3v694159714.urdf
# ./urdfs/AutoGen/divar3v8921748181.urdf
# ./urdfs/AutoGen/divar3v9804577515.urdf
# ./urdfs/AutoGen/divar3v6908964061.urdf
# ./urdfs/AutoGen/divar3v9308612746.urdf
# ./urdfs/AutoGen/divar3v2881461924.urdf
# ./urdfs/AutoGen/divar3v7781324408.urdf
# ./urdfs/AutoGen/divar3v4071189178.urdf
# ./urdfs/AutoGen/divar3v9231901995.urdf
# ./urdfs/AutoGen/divar3v1669369586.urdf
# ./urdfs/AutoGen/divar3v2101407020.urdf
# ./urdfs/AutoGen/divar3v4604116791.urdf
# ./urdfs/AutoGen/divar3v1346456359.urdf
# ./urdfs/AutoGen/divar3v6880883253.urdf
# ./urdfs/AutoGen/divar3v3190067386.urdf
# ./urdfs/AutoGen/divar3v4248955828.urdf
# ./urdfs/AutoGen/divar3v8828223183.urdf
# ./urdfs/AutoGen/divar3v2701473652.urdf
# ./urdfs/AutoGen/divar3v1598025311.urdf
# ./urdfs/AutoGen/divar3v3874256916.urdf
# ./urdfs/AutoGen/divar3v7972827364.urdf
# ./urdfs/AutoGen/divar3v8001521984.urdf
# ./urdfs/AutoGen/divar3v2836862695.urdf
# ./urdfs/AutoGen/divar3v7700276036.urdf
# ./urdfs/AutoGen/divar3v4626739508.urdf
# ./urdfs/AutoGen/divar3v1485657895.urdf
# ./urdfs/AutoGen/divar3v6200726483.urdf
# ./urdfs/AutoGen/divar3v284358327.urdf
# ./urdfs/AutoGen/divar3v8826862201.urdf
# ./urdfs/AutoGen/divar3v5261969720.urdf
# ./urdfs/AutoGen/divar3v5942327025.urdf
# ./urdfs/AutoGen/divar3v6022922233.urdf
# ./urdfs/AutoGen/divar3v5203701783.urdf
# ./urdfs/AutoGen/divar3v1189456863.urdf
# ./urdfs/AutoGen/divar3v5935360769.urdf
# ./urdfs/AutoGen/divar3v925441965.urdf
# ./urdfs/AutoGen/divar3v1415164194.urdf
# ./urdfs/AutoGen/divar3v982203235.urdf
# ./urdfs/AutoGen/divar3v7207506762.urdf
# ./urdfs/AutoGen/divar3v1045197072.urdf
# ./urdfs/AutoGen/divar3v5289534809.urdf
# ./urdfs/AutoGen/divar3v6770878246.urdf
# ./urdfs/AutoGen/divar3v5200114229.urdf
# ./urdfs/AutoGen/divar3v1602335839.urdf
# ./urdfs/AutoGen/divar3v8341912106.urdf
# ./urdfs/AutoGen/divar3v5186908624.urdf
# ./urdfs/AutoGen/divar3v8079073153.urdf
# ./urdfs/AutoGen/divar3v7067165304.urdf
# ./urdfs/AutoGen/divar3v6028201040.urdf
# ./urdfs/AutoGen/divar3v1456923541.urdf
# ./urdfs/AutoGen/divar3v1463466074.urdf
# ./urdfs/AutoGen/divar3v450599387.urdf
# ./urdfs/AutoGen/divar3v2050518812.urdf
# ./urdfs/AutoGen/divar3v8737342817.urdf
# ./urdfs/AutoGen/divar3v234692232.urdf
# ./urdfs/AutoGen/divar3v8882246857.urdf
# ./urdfs/AutoGen/divar3v9527647799.urdf
# ./urdfs/AutoGen/divar3v2212500283.urdf
# ./urdfs/AutoGen/divar3v6025797563.urdf
# ./urdfs/AutoGen/divar3v4262819882.urdf
# ./urdfs/AutoGen/divar3v1393403560.urdf
# CMAES 4 PaGMO:
# mu: 150 - lambda: 300 - mueff: 78.031 - N: 19
# cc: 0.259722 - cs: 0.784379 - c1: 0.00408063 - cmu: 0.293022 - sigma: 0.3 - damps: 3.70945 - chiN: 4.30212
# ./urdfs/AutoGen/divar3v5775006465.urdf
# ./urdfs/AutoGen/divar3v4372340748.urdf
# ./urdfs/AutoGen/divar3v9322277836.urdf
# ./urdfs/AutoGen/divar3v6011297810.urdf
# ./urdfs/AutoGen/divar3v1351764185.urdf
# ./urdfs/AutoGen/divar3v3858524031.urdf
# ./urdfs/AutoGen/divar3v8998238355.urdf
# ./urdfs/AutoGen/divar3v4067544001.urdf
# ./urdfs/AutoGen/divar3v1242384094.urdf
# ./urdfs/AutoGen/divar3v7556196332.urdf
# ./urdfs/AutoGen/divar3v4134220443.urdf
# ./urdfs/AutoGen/divar3v9259572579.urdf
# ./urdfs/AutoGen/divar3v3930770944.urdf
# ./urdfs/AutoGen/divar3v1315070813.urdf
# ./urdfs/AutoGen/divar3v8936447490.urdf
# ./urdfs/AutoGen/divar3v880218352.urdf
# ./urdfs/AutoGen/divar3v3296857602.urdf
# ./urdfs/AutoGen/divar3v6932332465.urdf
# ./urdfs/AutoGen/divar3v9886854655.urdf
# ./urdfs/AutoGen/divar3v6757339801.urdf
# ./urdfs/AutoGen/divar3v4590819612.urdf
# ./urdfs/AutoGen/divar3v6410507780.urdf
# ./urdfs/AutoGen/divar3v8386097457.urdf
# ./urdfs/AutoGen/divar3v6537176158.urdf
# ./urdfs/AutoGen/divar3v5316281591.urdf
# ./urdfs/AutoGen/divar3v3977800404.urdf
# ./urdfs/AutoGen/divar3v8239612410.urdf
# ./urdfs/AutoGen/divar3v5357105507.urdf
# ./urdfs/AutoGen/divar3v5175864862.urdf
# ./urdfs/AutoGen/divar3v1221526028.urdf
# ./urdfs/AutoGen/divar3v142192917.urdf
# ./urdfs/AutoGen/divar3v3556857647.urdf
# ./urdfs/AutoGen/divar3v2902009650.urdf
# ./urdfs/AutoGen/divar3v6342760996.urdf
# ./urdfs/AutoGen/divar3v8727594380.urdf
# ./urdfs/AutoGen/divar3v8826245693.urdf
# ./urdfs/AutoGen/divar3v4158945964.urdf
# ./urdfs/AutoGen/divar3v6384734142.urdf
# ./urdfs/AutoGen/divar3v8906189133.urdf
# ./urdfs/AutoGen/divar3v2543266959.urdf
# ./urdfs/AutoGen/divar3v2697793391.urdf
# ./urdfs/AutoGen/divar3v6136183929.urdf
# ./urdfs/AutoGen/divar3v974968557.urdf
# ./urdfs/AutoGen/divar3v9829679205.urdf
# ./urdfs/AutoGen/divar3v7865733931.urdf
# ./urdfs/AutoGen/divar3v1638046756.urdf
# ./urdfs/AutoGen/divar3v7218883980.urdf
# ./urdfs/AutoGen/divar3v3718249130.urdf
# ./urdfs/AutoGen/divar3v8001010924.urdf
# ./urdfs/AutoGen/divar3v4680946427.urdf
# ./urdfs/AutoGen/divar3v5830899530.urdf
# ./urdfs/AutoGen/divar3v6730226747.urdf
# ./urdfs/AutoGen/divar3v4614639391.urdf
# ./urdfs/AutoGen/divar3v5457795793.urdf
# ./urdfs/AutoGen/divar3v1006292064.urdf
# ./urdfs/AutoGen/divar3v4070334324.urdf
# ./urdfs/AutoGen/divar3v8935637888.urdf
# ./urdfs/AutoGen/divar3v9267073700.urdf
# ./urdfs/AutoGen/divar3v3649119869.urdf
# ./urdfs/AutoGen/divar3v2982986436.urdf
# ./urdfs/AutoGen/divar3v5824615607.urdf
# ./urdfs/AutoGen/divar3v9237150811.urdf
# ./urdfs/AutoGen/divar3v9851446148.urdf
# ./urdfs/AutoGen/divar3v4669356091.urdf
# ./urdfs/AutoGen/divar3v4486583443.urdf
# ./urdfs/AutoGen/divar3v3985194635.urdf
# ./urdfs/AutoGen/divar3v7167937448.urdf
# ./urdfs/AutoGen/divar3v9424878955.urdf
# ./urdfs/AutoGen/divar3v4654393277.urdf
# ./urdfs/AutoGen/divar3v891298043.urdf
# ./urdfs/AutoGen/divar3v7253002256.urdf
# ./urdfs/AutoGen/divar3v8023518204.urdf
# ./urdfs/AutoGen/divar3v399043778.urdf
# ./urdfs/AutoGen/divar3v5608223875.urdf
# ./urdfs/AutoGen/divar3v8318914766.urdf
# ./urdfs/AutoGen/divar3v7509166690.urdf
# ./urdfs/AutoGen/divar3v1316564178.urdf
# ./urdfs/AutoGen/divar3v7774984085.urdf
# ./urdfs/AutoGen/divar3v8890281258.urdf
# ./urdfs/AutoGen/divar3v6521119499.urdf
# ./urdfs/AutoGen/divar3v6728298670.urdf
# ./urdfs/AutoGen/divar3v7812779836.urdf
# ./urdfs/AutoGen/divar3v2724844372.urdf
# ./urdfs/AutoGen/divar3v4220831098.urdf
# ./urdfs/AutoGen/divar3v1726953163.urdf
# ./urdfs/AutoGen/divar3v9473255631.urdf
# ./urdfs/AutoGen/divar3v865825702.urdf
# ./urdfs/AutoGen/divar3v2030728600.urdf
# ./urdfs/AutoGen/divar3v2527656006.urdf
# ./urdfs/AutoGen/divar3v4216957827.urdf
# ./urdfs/AutoGen/divar3v7012544244.urdf
# ./urdfs/AutoGen/divar3v5296870815.urdf
# ./urdfs/AutoGen/divar3v5448375656.urdf
# ./urdfs/AutoGen/divar3v1847693269.urdf
# ./urdfs/AutoGen/divar3v2047155914.urdf
# ./urdfs/AutoGen/divar3v3362466087.urdf
# ./urdfs/AutoGen/divar3v4513503444.urdf
# ./urdfs/AutoGen/divar3v9359660014.urdf
# ./urdfs/AutoGen/divar3v9939454676.urdf
# ./urdfs/AutoGen/divar3v7380595781.urdf
# ./urdfs/AutoGen/divar3v2758843868.urdf
# ./urdfs/AutoGen/divar3v8978362430.urdf
# ./urdfs/AutoGen/divar3v2974502603.urdf
# ./urdfs/AutoGen/divar3v8474789477.urdf
# ./urdfs/AutoGen/divar3v6551259327.urdf
# ./urdfs/AutoGen/divar3v2042200126.urdf
# ./urdfs/AutoGen/divar3v7728828642.urdf
# ./urdfs/AutoGen/divar3v1548297889.urdf
# ./urdfs/AutoGen/divar3v486299652.urdf
# ./urdfs/AutoGen/divar3v9910718979.urdf
# ./urdfs/AutoGen/divar3v9099117090.urdf
# ./urdfs/AutoGen/divar3v7181517987.urdf
# ./urdfs/AutoGen/divar3v3355863885.urdf
# ./urdfs/AutoGen/divar3v2599210424.urdf
# ./urdfs/AutoGen/divar3v4969411490.urdf
# ./urdfs/AutoGen/divar3v4717372464.urdf
# ./urdfs/AutoGen/divar3v4934873492.urdf
# ./urdfs/AutoGen/divar3v3911220065.urdf
# ./urdfs/AutoGen/divar3v5327916866.urdf
# ./urdfs/AutoGen/divar3v9185806097.urdf
# ./urdfs/AutoGen/divar3v5737528565.urdf
# ./urdfs/AutoGen/divar3v9834174830.urdf
# ./urdfs/AutoGen/divar3v5527247613.urdf
# ./urdfs/AutoGen/divar3v8267454445.urdf
# ./urdfs/AutoGen/divar3v7289696261.urdf
# ./urdfs/AutoGen/divar3v3761256957.urdf
# ./urdfs/AutoGen/divar3v5793788004.urdf
# ./urdfs/AutoGen/divar3v103155244.urdf
# ./urdfs/AutoGen/divar3v8208951284.urdf
# ./urdfs/AutoGen/divar3v491693224.urdf
# ./urdfs/AutoGen/divar3v3926410702.urdf
# ./urdfs/AutoGen/divar3v8115192285.urdf
# ./urdfs/AutoGen/divar3v7082535737.urdf
# ./urdfs/AutoGen/divar3v8126894685.urdf
# ./urdfs/AutoGen/divar3v824401080.urdf
# ./urdfs/AutoGen/divar3v2003669343.urdf
# ./urdfs/AutoGen/divar3v2219164063.urdf
# ./urdfs/AutoGen/divar3v2262159869.urdf
# ./urdfs/AutoGen/divar3v9035425003.urdf
# ./urdfs/AutoGen/divar3v5875395945.urdf
# ./urdfs/AutoGen/divar3v3109869846.urdf
# ./urdfs/AutoGen/divar3v5946404.urdf
# ./urdfs/AutoGen/divar3v3772945951.urdf
# ./urdfs/AutoGen/divar3v692557642.urdf
# ./urdfs/AutoGen/divar3v2300448449.urdf
# ./urdfs/AutoGen/divar3v5615750457.urdf
# ./urdfs/AutoGen/divar3v3607473018.urdf
# ./urdfs/AutoGen/divar3v881247231.urdf
# ./urdfs/AutoGen/divar3v2920346581.urdf
# ./urdfs/AutoGen/divar3v8285021485.urdf
# ./urdfs/AutoGen/divar3v4353311766.urdf
# ./urdfs/AutoGen/divar3v5931272219.urdf
# ./urdfs/AutoGen/divar3v2971516571.urdf
# ./urdfs/AutoGen/divar3v3638494020.urdf
# ./urdfs/AutoGen/divar3v7660363938.urdf
# ./urdfs/AutoGen/divar3v75867865.urdf
# ./urdfs/AutoGen/divar3v816218575.urdf
# ./urdfs/AutoGen/divar3v9246139715.urdf
# ./urdfs/AutoGen/divar3v226021603.urdf
# ./urdfs/AutoGen/divar3v5932670399.urdf
# ./urdfs/AutoGen/divar3v2541190698.urdf
# ./urdfs/AutoGen/divar3v3981380081.urdf
# ./urdfs/AutoGen/divar3v2548084248.urdf
# ./urdfs/AutoGen/divar3v4865493997.urdf
# ./urdfs/AutoGen/divar3v8048979294.urdf
# ./urdfs/AutoGen/divar3v334056646.urdf
# ./urdfs/AutoGen/divar3v6865060954.urdf
# ./urdfs/AutoGen/divar3v4439316949.urdf
# ./urdfs/AutoGen/divar3v8198513291.urdf
# ./urdfs/AutoGen/divar3v2679989329.urdf
# ./urdfs/AutoGen/divar3v135886830.urdf
# ./urdfs/AutoGen/divar3v6271683108.urdf
# ./urdfs/AutoGen/divar3v2752250985.urdf
# ./urdfs/AutoGen/divar3v8799258746.urdf
# ./urdfs/AutoGen/divar3v4818009055.urdf
# ./urdfs/AutoGen/divar3v4257987270.urdf
# ./urdfs/AutoGen/divar3v9815428598.urdf
# ./urdfs/AutoGen/divar3v373654243.urdf
# ./urdfs/AutoGen/divar3v1008869587.urdf
# ./urdfs/AutoGen/divar3v7584806048.urdf
# ./urdfs/AutoGen/divar3v4985089977.urdf
# ./urdfs/AutoGen/divar3v1751272796.urdf
# ./urdfs/AutoGen/divar3v9213299247.urdf
# ./urdfs/AutoGen/divar3v9822013049.urdf
# ./urdfs/AutoGen/divar3v8079901153.urdf
# ./urdfs/AutoGen/divar3v1188906145.urdf
# ./urdfs/AutoGen/divar3v7420487416.urdf
# ./urdfs/AutoGen/divar3v5759299064.urdf
# ./urdfs/AutoGen/divar3v6142298194.urdf
# ./urdfs/AutoGen/divar3v89410733.urdf
# ./urdfs/AutoGen/divar3v4266086155.urdf
# ./urdfs/AutoGen/divar3v1709301539.urdf
# ./urdfs/AutoGen/divar3v4305839245.urdf
# ./urdfs/AutoGen/divar3v8609131254.urdf
# ./urdfs/AutoGen/divar3v6664116251.urdf
# ./urdfs/AutoGen/divar3v8227416012.urdf
# ./urdfs/AutoGen/divar3v1382822869.urdf
# ./urdfs/AutoGen/divar3v9739310826.urdf
# ./urdfs/AutoGen/divar3v8045270122.urdf
# ./urdfs/AutoGen/divar3v7009675801.urdf
# ./urdfs/AutoGen/divar3v4001927420.urdf
# ./urdfs/AutoGen/divar3v6375420478.urdf
# ./urdfs/AutoGen/divar3v7938750418.urdf
# ./urdfs/AutoGen/divar3v9485969062.urdf
# ./urdfs/AutoGen/divar3v5575178729.urdf
# ./urdfs/AutoGen/divar3v5399254985.urdf
# ./urdfs/AutoGen/divar3v6785656050.urdf
# ./urdfs/AutoGen/divar3v9665871031.urdf
# ./urdfs/AutoGen/divar3v9097235589.urdf
# ./urdfs/AutoGen/divar3v8012443084.urdf
# ./urdfs/AutoGen/divar3v8697899140.urdf
# ./urdfs/AutoGen/divar3v5866815945.urdf
# ./urdfs/AutoGen/divar3v6383403361.urdf
# ./urdfs/AutoGen/divar3v3253679170.urdf
# ./urdfs/AutoGen/divar3v5261169511.urdf
# ./urdfs/AutoGen/divar3v3238813603.urdf
# ./urdfs/AutoGen/divar3v9227269270.urdf
# ./urdfs/AutoGen/divar3v500414612.urdf
# ./urdfs/AutoGen/divar3v2606342652.urdf
# ./urdfs/AutoGen/divar3v1660068264.urdf
# ./urdfs/AutoGen/divar3v2639112918.urdf
# ./urdfs/AutoGen/divar3v4418630590.urdf
# ./urdfs/AutoGen/divar3v992671565.urdf
# ./urdfs/AutoGen/divar3v9875353905.urdf
# ./urdfs/AutoGen/divar3v5840886472.urdf
# ./urdfs/AutoGen/divar3v8715203630.urdf
# ./urdfs/AutoGen/divar3v3662887014.urdf
# ./urdfs/AutoGen/divar3v746195381.urdf
# ./urdfs/AutoGen/divar3v9712292380.urdf
# ./urdfs/AutoGen/divar3v8371948373.urdf
# ./urdfs/AutoGen/divar3v266873880.urdf
# ./urdfs/AutoGen/divar3v5733872481.urdf
# ./urdfs/AutoGen/divar3v9815012517.urdf
# ./urdfs/AutoGen/divar3v320020756.urdf
# ./urdfs/AutoGen/divar3v242199809.urdf
# ./urdfs/AutoGen/divar3v2697970026.urdf
# ./urdfs/AutoGen/divar3v5958922206.urdf
# ./urdfs/AutoGen/divar3v5667359331.urdf
# ./urdfs/AutoGen/divar3v2906414850.urdf
# ./urdfs/AutoGen/divar3v684443750.urdf
# ./urdfs/AutoGen/divar3v7563408925.urdf
# ./urdfs/AutoGen/divar3v8112183835.urdf
# ./urdfs/AutoGen/divar3v3351504686.urdf
# ./urdfs/AutoGen/divar3v330268932.urdf
# ./urdfs/AutoGen/divar3v9075633251.urdf
# ./urdfs/AutoGen/divar3v1994031601.urdf
# ./urdfs/AutoGen/divar3v1799682005.urdf
# ./urdfs/AutoGen/divar3v3152368351.urdf
# ./urdfs/AutoGen/divar3v9258338267.urdf
# ./urdfs/AutoGen/divar3v5841606288.urdf
# ./urdfs/AutoGen/divar3v9783667752.urdf
# ./urdfs/AutoGen/divar3v4528898453.urdf
# ./urdfs/AutoGen/divar3v2864287330.urdf
# ./urdfs/AutoGen/divar3v572781934.urdf
# ./urdfs/AutoGen/divar3v5376608034.urdf
# ./urdfs/AutoGen/divar3v4252723479.urdf
# ./urdfs/AutoGen/divar3v3952336671.urdf
# ./urdfs/AutoGen/divar3v5830453576.urdf
# ./urdfs/AutoGen/divar3v4885688203.urdf
# ./urdfs/AutoGen/divar3v8809379889.urdf
# ./urdfs/AutoGen/divar3v9591957087.urdf
# ./urdfs/AutoGen/divar3v3517006873.urdf
# ./urdfs/AutoGen/divar3v7755654187.urdf
# ./urdfs/AutoGen/divar3v3149509741.urdf
# ./urdfs/AutoGen/divar3v4604514729.urdf
# ./urdfs/AutoGen/divar3v1200749731.urdf
# ./urdfs/AutoGen/divar3v7791455958.urdf
# ./urdfs/AutoGen/divar3v1189679712.urdf
# ./urdfs/AutoGen/divar3v4702156371.urdf
# ./urdfs/AutoGen/divar3v4918035475.urdf
# ./urdfs/AutoGen/divar3v1692825944.urdf
# ./urdfs/AutoGen/divar3v9259967361.urdf
# ./urdfs/AutoGen/divar3v5946347638.urdf
# ./urdfs/AutoGen/divar3v4282723300.urdf
# ./urdfs/AutoGen/divar3v5361242498.urdf
# ./urdfs/AutoGen/divar3v1191819145.urdf
# ./urdfs/AutoGen/divar3v6871645355.urdf
# ./urdfs/AutoGen/divar3v3970691658.urdf
# ./urdfs/AutoGen/divar3v5604943833.urdf
# ./urdfs/AutoGen/divar3v9390725023.urdf
# ./urdfs/AutoGen/divar3v5015323186.urdf
# ./urdfs/AutoGen/divar3v7827962530.urdf
# ./urdfs/AutoGen/divar3v6099052635.urdf
# ./urdfs/AutoGen/divar3v497313446.urdf
# ./urdfs/AutoGen/divar3v3803571179.urdf
# ./urdfs/AutoGen/divar3v6127283705.urdf
# ./urdfs/AutoGen/divar3v9544474260.urdf
# ./urdfs/AutoGen/divar3v6997428099.urdf
# ./urdfs/AutoGen/divar3v4162912634.urdf
# ./urdfs/AutoGen/divar3v4436572047.urdf
# ./urdfs/AutoGen/divar3v1906791479.urdf
# ./urdfs/AutoGen/divar3v7327684941.urdf
# ./urdfs/AutoGen/divar3v7812837610.urdf
# ./urdfs/AutoGen/divar3v3378790610.urdf
# ./urdfs/AutoGen/divar3v1167193469.urdf
# ./urdfs/AutoGen/divar3v8875669269.urdf
# ./urdfs/AutoGen/divar3v599642582.urdf
# ./urdfs/AutoGen/divar3v4348481401.urdf
# ./urdfs/AutoGen/divar3v6292926779.urdf
# ./urdfs/AutoGen/divar3v8330383764.urdf
# ./urdfs/AutoGen/divar3v7851848463.urdf
# ./urdfs/AutoGen/divar3v7054652798.urdf
# ./urdfs/AutoGen/divar3v3818372063.urdf
# ./urdfs/AutoGen/divar3v4014985053.urdf
# ./urdfs/AutoGen/divar3v7178862047.urdf
# ./urdfs/AutoGen/divar3v6115338948.urdf
# ./urdfs/AutoGen/divar3v3439163432.urdf
# ./urdfs/AutoGen/divar3v1065062850.urdf
# ./urdfs/AutoGen/divar3v5320693739.urdf
# ./urdfs/AutoGen/divar3v7216007209.urdf
# ./urdfs/AutoGen/divar3v7157604249.urdf
# ./urdfs/AutoGen/divar3v5227547070.urdf
# ./urdfs/AutoGen/divar3v2995777937.urdf
# ./urdfs/AutoGen/divar3v4099585301.urdf
# ./urdfs/AutoGen/divar3v3630557206.urdf
# ./urdfs/AutoGen/divar3v904840880.urdf
# ./urdfs/AutoGen/divar3v251908778.urdf
# ./urdfs/AutoGen/divar3v7689865581.urdf
# ./urdfs/AutoGen/divar3v6558547161.urdf
# ./urdfs/AutoGen/divar3v6523665040.urdf
# ./urdfs/AutoGen/divar3v9966573440.urdf
# ./urdfs/AutoGen/divar3v2349911686.urdf
# ./urdfs/AutoGen/divar3v2268411821.urdf
# ./urdfs/AutoGen/divar3v515772348.urdf
# ./urdfs/AutoGen/divar3v2070664767.urdf
# ./urdfs/AutoGen/divar3v2016122761.urdf
# ./urdfs/AutoGen/divar3v6461006112.urdf
# ./urdfs/AutoGen/divar3v5129238180.urdf
# ./urdfs/AutoGen/divar3v8864320398.urdf
# ./urdfs/AutoGen/divar3v4942607218.urdf
# ./urdfs/AutoGen/divar3v4268021299.urdf
# ./urdfs/AutoGen/divar3v7662764620.urdf
# ./urdfs/AutoGen/divar3v2249538546.urdf
# ./urdfs/AutoGen/divar3v5391709617.urdf
# ./urdfs/AutoGen/divar3v8008853824.urdf
# ./urdfs/AutoGen/divar3v1874097469.urdf
# ./urdfs/AutoGen/divar3v957577582.urdf
# ./urdfs/AutoGen/divar3v3001419121.urdf
# ./urdfs/AutoGen/divar3v7859987829.urdf
# ./urdfs/AutoGen/divar3v7613441009.urdf
# ./urdfs/AutoGen/divar3v4697698316.urdf
# ./urdfs/AutoGen/divar3v1653899244.urdf
# ./urdfs/AutoGen/divar3v9929223979.urdf
# ./urdfs/AutoGen/divar3v7710772994.urdf
# ./urdfs/AutoGen/divar3v7032166020.urdf
# ./urdfs/AutoGen/divar3v4197918032.urdf
# ./urdfs/AutoGen/divar3v1183746763.urdf
# ./urdfs/AutoGen/divar3v6195811866.urdf
# ./urdfs/AutoGen/divar3v1209917448.urdf
# ./urdfs/AutoGen/divar3v6739897874.urdf
# ./urdfs/AutoGen/divar3v5146080134.urdf
# ./urdfs/AutoGen/divar3v7032864233.urdf
# ./urdfs/AutoGen/divar3v6854773825.urdf
# ./urdfs/AutoGen/divar3v5229649900.urdf
# ./urdfs/AutoGen/divar3v6595866540.urdf
# ./urdfs/AutoGen/divar3v3592939633.urdf
# ./urdfs/AutoGen/divar3v5760415315.urdf
# ./urdfs/AutoGen/divar3v7660335412.urdf
# ./urdfs/AutoGen/divar3v4947480383.urdf
# ./urdfs/AutoGen/divar3v3428995325.urdf
# ./urdfs/AutoGen/divar3v1742229323.urdf
# ./urdfs/AutoGen/divar3v2534304167.urdf
# ./urdfs/AutoGen/divar3v4594702344.urdf
# ./urdfs/AutoGen/divar3v7857056688.urdf
# ./urdfs/AutoGen/divar3v3472588281.urdf
# ./urdfs/AutoGen/divar3v3362339569.urdf
# ./urdfs/AutoGen/divar3v9457200133.urdf
# ./urdfs/AutoGen/divar3v5420009650.urdf
# ./urdfs/AutoGen/divar3v6362252152.urdf
# ./urdfs/AutoGen/divar3v2827595564.urdf
# ./urdfs/AutoGen/divar3v7752529191.urdf
# ./urdfs/AutoGen/divar3v4757522418.urdf
# ./urdfs/AutoGen/divar3v9215898566.urdf
# ./urdfs/AutoGen/divar3v4397882210.urdf
# ./urdfs/AutoGen/divar3v3330296511.urdf
# ./urdfs/AutoGen/divar3v3473134960.urdf
# ./urdfs/AutoGen/divar3v3981907860.urdf
# ./urdfs/AutoGen/divar3v3109846208.urdf
# ./urdfs/AutoGen/divar3v107312292.urdf
# ./urdfs/AutoGen/divar3v5588725221.urdf
# ./urdfs/AutoGen/divar3v6712337105.urdf
# ./urdfs/AutoGen/divar3v414951093.urdf
# ./urdfs/AutoGen/divar3v5274771648.urdf
# ./urdfs/AutoGen/divar3v4205240751.urdf
# ./urdfs/AutoGen/divar3v6167945221.urdf
# ./urdfs/AutoGen/divar3v6903829275.urdf
# ./urdfs/AutoGen/divar3v7103207794.urdf
# ./urdfs/AutoGen/divar3v9981398338.urdf
# ./urdfs/AutoGen/divar3v2672103367.urdf
# ./urdfs/AutoGen/divar3v9147209234.urdf
# ./urdfs/AutoGen/divar3v4748843929.urdf
# ./urdfs/AutoGen/divar3v8199672654.urdf
# ./urdfs/AutoGen/divar3v1558885983.urdf
# ./urdfs/AutoGen/divar3v2681100755.urdf
# ./urdfs/AutoGen/divar3v9673688346.urdf
# ./urdfs/AutoGen/divar3v6775479197.urdf
# ./urdfs/AutoGen/divar3v6667865696.urdf
# ./urdfs/AutoGen/divar3v3467331885.urdf
# ./urdfs/AutoGen/divar3v5743402695.urdf
# ./urdfs/AutoGen/divar3v4139532769.urdf
# ./urdfs/AutoGen/divar3v4796236662.urdf
# ./urdfs/AutoGen/divar3v7494195371.urdf
# ./urdfs/AutoGen/divar3v9008683098.urdf
# ./urdfs/AutoGen/divar3v4352531193.urdf
# ./urdfs/AutoGen/divar3v2611411400.urdf
# ./urdfs/AutoGen/divar3v3089752849.urdf
# ./urdfs/AutoGen/divar3v6419401444.urdf
# ./urdfs/AutoGen/divar3v7816249172.urdf
# ./urdfs/AutoGen/divar3v3903248076.urdf
# ./urdfs/AutoGen/divar3v8262120040.urdf
# ./urdfs/AutoGen/divar3v8172858804.urdf
# ./urdfs/AutoGen/divar3v9651374920.urdf
# ./urdfs/AutoGen/divar3v65953942.urdf
# ./urdfs/AutoGen/divar3v2918792701.urdf
# ./urdfs/AutoGen/divar3v3016226540.urdf
# ./urdfs/AutoGen/divar3v5527852155.urdf
# ./urdfs/AutoGen/divar3v793251451.urdf
# ./urdfs/AutoGen/divar3v2192929133.urdf
# ./urdfs/AutoGen/divar3v4109611390.urdf
# ./urdfs/AutoGen/divar3v2177157757.urdf
# ./urdfs/AutoGen/divar3v2559388358.urdf
# ./urdfs/AutoGen/divar3v7801728038.urdf
# ./urdfs/AutoGen/divar3v2178768745.urdf
# ./urdfs/AutoGen/divar3v2482955842.urdf
# ./urdfs/AutoGen/divar3v4645282017.urdf
# ./urdfs/AutoGen/divar3v2943487614.urdf
# ./urdfs/AutoGen/divar3v6943293565.urdf
# ./urdfs/AutoGen/divar3v7078509550.urdf
# ./urdfs/AutoGen/divar3v7030846079.urdf
# ./urdfs/AutoGen/divar3v8859355617.urdf
# ./urdfs/AutoGen/divar3v3526522675.urdf
# ./urdfs/AutoGen/divar3v2519475248.urdf
# ./urdfs/AutoGen/divar3v7866041238.urdf
# ./urdfs/AutoGen/divar3v583864055.urdf
# ./urdfs/AutoGen/divar3v8907891708.urdf
# ./urdfs/AutoGen/divar3v659970290.urdf
# ./urdfs/AutoGen/divar3v4788815909.urdf
# ./urdfs/AutoGen/divar3v2511340487.urdf
# ./urdfs/AutoGen/divar3v5258420498.urdf
# ./urdfs/AutoGen/divar3v3016174904.urdf
# ./urdfs/AutoGen/divar3v6432036431.urdf
# ./urdfs/AutoGen/divar3v4480600498.urdf
# ./urdfs/AutoGen/divar3v4913846609.urdf
# ./urdfs/AutoGen/divar3v4448904611.urdf
# ./urdfs/AutoGen/divar3v3782145832.urdf
# ./urdfs/AutoGen/divar3v6627067733.urdf
# ./urdfs/AutoGen/divar3v7889987683.urdf
# ./urdfs/AutoGen/divar3v122258757.urdf
# ./urdfs/AutoGen/divar3v1790814994.urdf
# ./urdfs/AutoGen/divar3v1160689569.urdf
# ./urdfs/AutoGen/divar3v9244595431.urdf
# ./urdfs/AutoGen/divar3v2901601842.urdf
# ./urdfs/AutoGen/divar3v6912501928.urdf
# ./urdfs/AutoGen/divar3v6534625954.urdf
# ./urdfs/AutoGen/divar3v9652540292.urdf
# ./urdfs/AutoGen/divar3v5366249865.urdf
# ./urdfs/AutoGen/divar3v1841468472.urdf
# ./urdfs/AutoGen/divar3v5358481761.urdf
# ./urdfs/AutoGen/divar3v6473029343.urdf
# ./urdfs/AutoGen/divar3v6780357188.urdf
# ./urdfs/AutoGen/divar3v831710392.urdf
# ./urdfs/AutoGen/divar3v3382110162.urdf
# ./urdfs/AutoGen/divar3v9673490639.urdf
# ./urdfs/AutoGen/divar3v6235396258.urdf
# ./urdfs/AutoGen/divar3v7408232837.urdf
# ./urdfs/AutoGen/divar3v494461376.urdf
# ./urdfs/AutoGen/divar3v7805752951.urdf
# ./urdfs/AutoGen/divar3v4138405207.urdf
# ./urdfs/AutoGen/divar3v7138746918.urdf
# ./urdfs/AutoGen/divar3v62810346.urdf
# ./urdfs/AutoGen/divar3v1410876986.urdf
# ./urdfs/AutoGen/divar3v3869599506.urdf
# ./urdfs/AutoGen/divar3v659048013.urdf
# ./urdfs/AutoGen/divar3v2306442206.urdf
# ./urdfs/AutoGen/divar3v7019171337.urdf
# ./urdfs/AutoGen/divar3v2032708900.urdf
# ./urdfs/AutoGen/divar3v1105799759.urdf
# ./urdfs/AutoGen/divar3v6566956827.urdf
# ./urdfs/AutoGen/divar3v7401363203.urdf
# ./urdfs/AutoGen/divar3v450828115.urdf
# ./urdfs/AutoGen/divar3v3125726628.urdf
# ./urdfs/AutoGen/divar3v5471650253.urdf
# ./urdfs/AutoGen/divar3v3586244983.urdf
# ./urdfs/AutoGen/divar3v6516745365.urdf
# ./urdfs/AutoGen/divar3v1044213798.urdf
# ./urdfs/AutoGen/divar3v6736649873.urdf
# ./urdfs/AutoGen/divar3v3045660648.urdf
# ./urdfs/AutoGen/divar3v8124648543.urdf
# ./urdfs/AutoGen/divar3v3397824169.urdf
# ./urdfs/AutoGen/divar3v8619699796.urdf
# ./urdfs/AutoGen/divar3v2611782675.urdf
# ./urdfs/AutoGen/divar3v52936915.urdf
# ./urdfs/AutoGen/divar3v2283618029.urdf
# ./urdfs/AutoGen/divar3v1075289333.urdf
# ./urdfs/AutoGen/divar3v7063881845.urdf
# ./urdfs/AutoGen/divar3v3513964109.urdf
# ./urdfs/AutoGen/divar3v2532032418.urdf
# ./urdfs/AutoGen/divar3v7970859324.urdf
# ./urdfs/AutoGen/divar3v1802454532.urdf
# ./urdfs/AutoGen/divar3v1442399528.urdf
# ./urdfs/AutoGen/divar3v5013717917.urdf
# ./urdfs/AutoGen/divar3v822057642.urdf
# ./urdfs/AutoGen/divar3v2046745465.urdf
# ./urdfs/AutoGen/divar3v8536838470.urdf
# ./urdfs/AutoGen/divar3v7524398965.urdf
# ./urdfs/AutoGen/divar3v5918835131.urdf
# ./urdfs/AutoGen/divar3v5901731718.urdf
# ./urdfs/AutoGen/divar3v5597326913.urdf
# ./urdfs/AutoGen/divar3v7342985049.urdf
# ./urdfs/AutoGen/divar3v5258743438.urdf
# ./urdfs/AutoGen/divar3v6016320921.urdf
# ./urdfs/AutoGen/divar3v638279257.urdf
# ./urdfs/AutoGen/divar3v9068335839.urdf
# ./urdfs/AutoGen/divar3v6868875972.urdf
# ./urdfs/AutoGen/divar3v357674184.urdf
# ./urdfs/AutoGen/divar3v9644078611.urdf
# ./urdfs/AutoGen/divar3v663546082.urdf
# ./urdfs/AutoGen/divar3v3436309358.urdf
# ./urdfs/AutoGen/divar3v5056272908.urdf
# ./urdfs/AutoGen/divar3v2662136673.urdf
# ./urdfs/AutoGen/divar3v2326421262.urdf
# ./urdfs/AutoGen/divar3v8922788577.urdf
# ./urdfs/AutoGen/divar3v573705546.urdf
# ./urdfs/AutoGen/divar3v6810598163.urdf
# ./urdfs/AutoGen/divar3v3824320924.urdf
# ./urdfs/AutoGen/divar3v3420485712.urdf
# ./urdfs/AutoGen/divar3v1697055408.urdf
# ./urdfs/AutoGen/divar3v7535701093.urdf
# ./urdfs/AutoGen/divar3v9704068228.urdf
# ./urdfs/AutoGen/divar3v5471767840.urdf
# ./urdfs/AutoGen/divar3v9029341433.urdf
# ./urdfs/AutoGen/divar3v7307388431.urdf
# ./urdfs/AutoGen/divar3v5156727010.urdf
# ./urdfs/AutoGen/divar3v7760813407.urdf
# ./urdfs/AutoGen/divar3v384680422.urdf
# ./urdfs/AutoGen/divar3v7497600428.urdf
# ./urdfs/AutoGen/divar3v1958871969.urdf
# ./urdfs/AutoGen/divar3v6319405216.urdf
# ./urdfs/AutoGen/divar3v9542569157.urdf
# ./urdfs/AutoGen/divar3v3174874675.urdf
# ./urdfs/AutoGen/divar3v6314323660.urdf
# ./urdfs/AutoGen/divar3v6285576199.urdf
# ./urdfs/AutoGen/divar3v6370022165.urdf
# ./urdfs/AutoGen/divar3v3974346384.urdf
# ./urdfs/AutoGen/divar3v5588189273.urdf
# ./urdfs/AutoGen/divar3v5025273927.urdf
# ./urdfs/AutoGen/divar3v1118643793.urdf
# ./urdfs/AutoGen/divar3v5803727645.urdf
# ./urdfs/AutoGen/divar3v5624875777.urdf
# ./urdfs/AutoGen/divar3v159549180.urdf
# ./urdfs/AutoGen/divar3v6783848750.urdf
# ./urdfs/AutoGen/divar3v9873651496.urdf
# ./urdfs/AutoGen/divar3v699025495.urdf
# ./urdfs/AutoGen/divar3v3912758243.urdf
# ./urdfs/AutoGen/divar3v2976468821.urdf
# ./urdfs/AutoGen/divar3v4451016545.urdf
# ./urdfs/AutoGen/divar3v3823483730.urdf
# ./urdfs/AutoGen/divar3v9067608789.urdf
# ./urdfs/AutoGen/divar3v9148567861.urdf
# ./urdfs/AutoGen/divar3v2295523661.urdf
# ./urdfs/AutoGen/divar3v9396093016.urdf
# ./urdfs/AutoGen/divar3v2731767538.urdf
# ./urdfs/AutoGen/divar3v1350331202.urdf
# ./urdfs/AutoGen/divar3v9394254972.urdf
# ./urdfs/AutoGen/divar3v4629423643.urdf
# ./urdfs/AutoGen/divar3v3918652387.urdf
# ./urdfs/AutoGen/divar3v5046518811.urdf
# ./urdfs/AutoGen/divar3v5842802390.urdf
# ./urdfs/AutoGen/divar3v460968205.urdf
# ./urdfs/AutoGen/divar3v1219878622.urdf
# ./urdfs/AutoGen/divar3v27958034.urdf
# ./urdfs/AutoGen/divar3v6681296504.urdf
# ./urdfs/AutoGen/divar3v9368858024.urdf
# ./urdfs/AutoGen/divar3v2834468978.urdf
# ./urdfs/AutoGen/divar3v9935738227.urdf
# ./urdfs/AutoGen/divar3v4415224692.urdf
# ./urdfs/AutoGen/divar3v8135820907.urdf
# ./urdfs/AutoGen/divar3v479434719.urdf
# ./urdfs/AutoGen/divar3v9845795341.urdf
# ./urdfs/AutoGen/divar3v5388821039.urdf
# ./urdfs/AutoGen/divar3v425013039.urdf
# ./urdfs/AutoGen/divar3v1142527356.urdf
# ./urdfs/AutoGen/divar3v4141501492.urdf
# ./urdfs/AutoGen/divar3v4389507768.urdf
# ./urdfs/AutoGen/divar3v2140662585.urdf
# ./urdfs/AutoGen/divar3v5910373337.urdf
# ./urdfs/AutoGen/divar3v4041665340.urdf
# ./urdfs/AutoGen/divar3v2540674149.urdf
# ./urdfs/AutoGen/divar3v2656281622.urdf
# ./urdfs/AutoGen/divar3v3564192689.urdf
# ./urdfs/AutoGen/divar3v9553638171.urdf
# ./urdfs/AutoGen/divar3v7341873787.urdf
# ./urdfs/AutoGen/divar3v5498103337.urdf
# ./urdfs/AutoGen/divar3v7512242802.urdf
# ./urdfs/AutoGen/divar3v6710399126.urdf
# ./urdfs/AutoGen/divar3v2847019329.urdf
# ./urdfs/AutoGen/divar3v8482991363.urdf
# ./urdfs/AutoGen/divar3v7473265234.urdf
# ./urdfs/AutoGen/divar3v2973644982.urdf
# ./urdfs/AutoGen/divar3v9166264485.urdf
# ./urdfs/AutoGen/divar3v1793194663.urdf
# ./urdfs/AutoGen/divar3v6207839119.urdf
# ./urdfs/AutoGen/divar3v3282208074.urdf
# ./urdfs/AutoGen/divar3v2952685666.urdf
# ./urdfs/AutoGen/divar3v5890578704.urdf
# ./urdfs/AutoGen/divar3v136299773.urdf
# ./urdfs/AutoGen/divar3v1308332602.urdf
# ./urdfs/AutoGen/divar3v2358230870.urdf
# ./urdfs/AutoGen/divar3v936043222.urdf
# ./urdfs/AutoGen/divar3v206411871.urdf
# ./urdfs/AutoGen/divar3v5451555707.urdf
# ./urdfs/AutoGen/divar3v9337027496.urdf
# ./urdfs/AutoGen/divar3v5329337127.urdf
# ./urdfs/AutoGen/divar3v1578002144.urdf
# ./urdfs/AutoGen/divar3v9483393154.urdf
# ./urdfs/AutoGen/divar3v6299827262.urdf
# ./urdfs/AutoGen/divar3v9019095238.urdf
# ./urdfs/AutoGen/divar3v6557140462.urdf
# ./urdfs/AutoGen/divar3v3010171402.urdf
# ./urdfs/AutoGen/divar3v1599530297.urdf
# ./urdfs/AutoGen/divar3v4701419899.urdf
# ./urdfs/AutoGen/divar3v145835069.urdf
# ./urdfs/AutoGen/divar3v707636501.urdf
# ./urdfs/AutoGen/divar3v5395652346.urdf
# ./urdfs/AutoGen/divar3v811731668.urdf
# ./urdfs/AutoGen/divar3v9283366782.urdf
# ./urdfs/AutoGen/divar3v8283039523.urdf
# ./urdfs/AutoGen/divar3v6159210135.urdf
# ./urdfs/AutoGen/divar3v5928584983.urdf
# ./urdfs/AutoGen/divar3v6778285166.urdf
# ./urdfs/AutoGen/divar3v4559090039.urdf
# ./urdfs/AutoGen/divar3v6699829303.urdf
# ./urdfs/AutoGen/divar3v7515917456.urdf
# ./urdfs/AutoGen/divar3v9469538819.urdf
# ./urdfs/AutoGen/divar3v2884949008.urdf
# ./urdfs/AutoGen/divar3v2294302126.urdf
# ./urdfs/AutoGen/divar3v7676707604.urdf
# ./urdfs/AutoGen/divar3v1529197777.urdf
# ./urdfs/AutoGen/divar3v9372415052.urdf
# ./urdfs/AutoGen/divar3v4545407616.urdf
# ./urdfs/AutoGen/divar3v2494633581.urdf
# ./urdfs/AutoGen/divar3v250670708.urdf
# ./urdfs/AutoGen/divar3v6969827505.urdf
# ./urdfs/AutoGen/divar3v3992604442.urdf
# ./urdfs/AutoGen/divar3v8856503470.urdf
# ./urdfs/AutoGen/divar3v7508812764.urdf
# ./urdfs/AutoGen/divar3v3367925444.urdf
# ./urdfs/AutoGen/divar3v4952749337.urdf
# ./urdfs/AutoGen/divar3v9507366981.urdf
# ./urdfs/AutoGen/divar3v3834370765.urdf
# ./urdfs/AutoGen/divar3v5255163878.urdf
# ./urdfs/AutoGen/divar3v7461359110.urdf
# ./urdfs/AutoGen/divar3v7969494783.urdf
# ./urdfs/AutoGen/divar3v5820963727.urdf
# ./urdfs/AutoGen/divar3v7243510797.urdf
# ./urdfs/AutoGen/divar3v1303995419.urdf
# ./urdfs/AutoGen/divar3v8028909145.urdf
# ./urdfs/AutoGen/divar3v6620187049.urdf
# ./urdfs/AutoGen/divar3v3859504761.urdf
# ./urdfs/AutoGen/divar3v5542040601.urdf
# ./urdfs/AutoGen/divar3v8020619842.urdf
# ./urdfs/AutoGen/divar3v5223680822.urdf
# ./urdfs/AutoGen/divar3v6333553519.urdf
# ./urdfs/AutoGen/divar3v9411647452.urdf
# ./urdfs/AutoGen/divar3v2425220647.urdf
# ./urdfs/AutoGen/divar3v4297978318.urdf
# ./urdfs/AutoGen/divar3v1726860670.urdf
# ./urdfs/AutoGen/divar3v8328275077.urdf
# ./urdfs/AutoGen/divar3v6713115548.urdf
# ./urdfs/AutoGen/divar3v7087002555.urdf
# ./urdfs/AutoGen/divar3v2369572314.urdf
# ./urdfs/AutoGen/divar3v140536261.urdf
# ./urdfs/AutoGen/divar3v4146683402.urdf
# ./urdfs/AutoGen/divar3v6887571479.urdf
# ./urdfs/AutoGen/divar3v3185512088.urdf
# ./urdfs/AutoGen/divar3v5003828920.urdf
# ./urdfs/AutoGen/divar3v9372216317.urdf
# ./urdfs/AutoGen/divar3v4634751614.urdf
# ./urdfs/AutoGen/divar3v5586811983.urdf
# ./urdfs/AutoGen/divar3v7305110505.urdf
# ./urdfs/AutoGen/divar3v5013195459.urdf
# ./urdfs/AutoGen/divar3v8802738477.urdf
# ./urdfs/AutoGen/divar3v9522687814.urdf
# ./urdfs/AutoGen/divar3v5157077994.urdf
# ./urdfs/AutoGen/divar3v676058130.urdf
# ./urdfs/AutoGen/divar3v2559871760.urdf
# ./urdfs/AutoGen/divar3v831857444.urdf
# ./urdfs/AutoGen/divar3v9489491811.urdf
# ./urdfs/AutoGen/divar3v20342109.urdf
# ./urdfs/AutoGen/divar3v9161415478.urdf
# ./urdfs/AutoGen/divar3v8556580715.urdf
# ./urdfs/AutoGen/divar3v8179550523.urdf
# ./urdfs/AutoGen/divar3v8080571434.urdf
# ./urdfs/AutoGen/divar3v9407263862.urdf
# ./urdfs/AutoGen/divar3v3910394450.urdf
# ./urdfs/AutoGen/divar3v1803416944.urdf
# ./urdfs/AutoGen/divar3v3988215975.urdf
# ./urdfs/AutoGen/divar3v7981277439.urdf
# ./urdfs/AutoGen/divar3v7154446844.urdf
# ./urdfs/AutoGen/divar3v4327016975.urdf
# ./urdfs/AutoGen/divar3v6560806701.urdf
# ./urdfs/AutoGen/divar3v8637962636.urdf
# ./urdfs/AutoGen/divar3v3588544700.urdf
# ./urdfs/AutoGen/divar3v7468168561.urdf
# ./urdfs/AutoGen/divar3v2458342844.urdf
# ./urdfs/AutoGen/divar3v4037854215.urdf
# ./urdfs/AutoGen/divar3v6664082493.urdf
# ./urdfs/AutoGen/divar3v9190157243.urdf
# ./urdfs/AutoGen/divar3v176335824.urdf
# ./urdfs/AutoGen/divar3v2788589277.urdf
# ./urdfs/AutoGen/divar3v1226849972.urdf
# ./urdfs/AutoGen/divar3v4478959489.urdf
# ./urdfs/AutoGen/divar3v3886918276.urdf
# ./urdfs/AutoGen/divar3v9154337686.urdf
# ./urdfs/AutoGen/divar3v3937809174.urdf
# ./urdfs/AutoGen/divar3v5339290604.urdf
# ./urdfs/AutoGen/divar3v6915881374.urdf
# ./urdfs/AutoGen/divar3v4752585941.urdf
# ./urdfs/AutoGen/divar3v7875804031.urdf
# ./urdfs/AutoGen/divar3v4985282790.urdf
# ./urdfs/AutoGen/divar3v3517994937.urdf
# ./urdfs/AutoGen/divar3v219341605.urdf
# ./urdfs/AutoGen/divar3v9145489593.urdf
# ./urdfs/AutoGen/divar3v3687288126.urdf
# ./urdfs/AutoGen/divar3v6374580613.urdf
# ./urdfs/AutoGen/divar3v4523715147.urdf
# ./urdfs/AutoGen/divar3v3270330606.urdf
# ./urdfs/AutoGen/divar3v8769588919.urdf
# ./urdfs/AutoGen/divar3v2467152483.urdf
# ./urdfs/AutoGen/divar3v7575321029.urdf
# ./urdfs/AutoGen/divar3v8636183864.urdf
# ./urdfs/AutoGen/divar3v6768507237.urdf
# ./urdfs/AutoGen/divar3v7921686479.urdf
# ./urdfs/AutoGen/divar3v573618451.urdf
# ./urdfs/AutoGen/divar3v7125617047.urdf
# ./urdfs/AutoGen/divar3v7658235631.urdf
# ./urdfs/AutoGen/divar3v7023848283.urdf
# ./urdfs/AutoGen/divar3v7245592373.urdf
# ./urdfs/AutoGen/divar3v2518718016.urdf
# ./urdfs/AutoGen/divar3v5479494975.urdf
# ./urdfs/AutoGen/divar3v3041703280.urdf
# ./urdfs/AutoGen/divar3v5130939062.urdf
# ./urdfs/AutoGen/divar3v9821827842.urdf
# ./urdfs/AutoGen/divar3v9103480373.urdf
# ./urdfs/AutoGen/divar3v388980623.urdf
# ./urdfs/AutoGen/divar3v5464653866.urdf
# ./urdfs/AutoGen/divar3v5053232462.urdf
# ./urdfs/AutoGen/divar3v6098451309.urdf
# ./urdfs/AutoGen/divar3v373443938.urdf
# ./urdfs/AutoGen/divar3v5592395301.urdf
# ./urdfs/AutoGen/divar3v9769961318.urdf
# ./urdfs/AutoGen/divar3v4183295200.urdf
# ./urdfs/AutoGen/divar3v5370190952.urdf
# ./urdfs/AutoGen/divar3v7046946149.urdf
# ./urdfs/AutoGen/divar3v9852762344.urdf
# ./urdfs/AutoGen/divar3v3121848654.urdf
# ./urdfs/AutoGen/divar3v2099496381.urdf
# ./urdfs/AutoGen/divar3v2238385582.urdf
# ./urdfs/AutoGen/divar3v9066011790.urdf
# ./urdfs/AutoGen/divar3v6898912427.urdf
# ./urdfs/AutoGen/divar3v4948766790.urdf
# ./urdfs/AutoGen/divar3v7667335049.urdf
# ./urdfs/AutoGen/divar3v4799162638.urdf
# ./urdfs/AutoGen/divar3v4603126006.urdf
# ./urdfs/AutoGen/divar3v8237780943.urdf
# ./urdfs/AutoGen/divar3v4523343403.urdf
# ./urdfs/AutoGen/divar3v2593930968.urdf
# ./urdfs/AutoGen/divar3v2560421949.urdf
# ./urdfs/AutoGen/divar3v2220884325.urdf
# ./urdfs/AutoGen/divar3v6568013130.urdf
# ./urdfs/AutoGen/divar3v5341639078.urdf
# ./urdfs/AutoGen/divar3v372195804.urdf
# ./urdfs/AutoGen/divar3v6790521972.urdf
# ./urdfs/AutoGen/divar3v2303193765.urdf
# ./urdfs/AutoGen/divar3v2265393039.urdf
# ./urdfs/AutoGen/divar3v5019216899.urdf
# ./urdfs/AutoGen/divar3v8576074549.urdf
# ./urdfs/AutoGen/divar3v6337908069.urdf
# ./urdfs/AutoGen/divar3v3938758621.urdf
# ./urdfs/AutoGen/divar3v5125077315.urdf
# ./urdfs/AutoGen/divar3v850093008.urdf
# ./urdfs/AutoGen/divar3v7213994838.urdf
# ./urdfs/AutoGen/divar3v7763507512.urdf
# ./urdfs/AutoGen/divar3v8439738385.urdf
# ./urdfs/AutoGen/divar3v9170214553.urdf
# ./urdfs/AutoGen/divar3v1325931379.urdf
# ./urdfs/AutoGen/divar3v1722859742.urdf
# ./urdfs/AutoGen/divar3v8837575780.urdf
# ./urdfs/AutoGen/divar3v6946151426.urdf
# ./urdfs/AutoGen/divar3v1492119285.urdf
# ./urdfs/AutoGen/divar3v1842288975.urdf
# ./urdfs/AutoGen/divar3v4316671453.urdf
# ./urdfs/AutoGen/divar3v2613288835.urdf
# ./urdfs/AutoGen/divar3v4038220630.urdf
# ./urdfs/AutoGen/divar3v7589802341.urdf
# ./urdfs/AutoGen/divar3v1283080859.urdf
# ./urdfs/AutoGen/divar3v8420824065.urdf
# ./urdfs/AutoGen/divar3v8592081297.urdf
# ./urdfs/AutoGen/divar3v2359269082.urdf
# ./urdfs/AutoGen/divar3v5001397751.urdf
# ./urdfs/AutoGen/divar3v2126841129.urdf
# ./urdfs/AutoGen/divar3v8626320855.urdf
# ./urdfs/AutoGen/divar3v3753163363.urdf
# ./urdfs/AutoGen/divar3v767615184.urdf
# ./urdfs/AutoGen/divar3v7159725273.urdf
# ./urdfs/AutoGen/divar3v9120061550.urdf
# ./urdfs/AutoGen/divar3v232419563.urdf
# ./urdfs/AutoGen/divar3v4385830769.urdf
# ./urdfs/AutoGen/divar3v9485496448.urdf
# ./urdfs/AutoGen/divar3v2465006070.urdf
# ./urdfs/AutoGen/divar3v4446372734.urdf
# ./urdfs/AutoGen/divar3v2316850757.urdf
# ./urdfs/AutoGen/divar3v2134233989.urdf
# ./urdfs/AutoGen/divar3v1552010133.urdf
# ./urdfs/AutoGen/divar3v3984527744.urdf
# ./urdfs/AutoGen/divar3v6525117346.urdf
# ./urdfs/AutoGen/divar3v1190666219.urdf
# ./urdfs/AutoGen/divar3v5471811815.urdf
# ./urdfs/AutoGen/divar3v7633921801.urdf
# ./urdfs/AutoGen/divar3v4908907954.urdf
# ./urdfs/AutoGen/divar3v8196353356.urdf
# ./urdfs/AutoGen/divar3v9375344457.urdf
# ./urdfs/AutoGen/divar3v7574296327.urdf
# ./urdfs/AutoGen/divar3v9970738786.urdf
# ./urdfs/AutoGen/divar3v392833733.urdf
# ./urdfs/AutoGen/divar3v5145103095.urdf
# ./urdfs/AutoGen/divar3v6391602946.urdf
# ./urdfs/AutoGen/divar3v9282920269.urdf
# ./urdfs/AutoGen/divar3v5239770577.urdf
# ./urdfs/AutoGen/divar3v6200595449.urdf
# ./urdfs/AutoGen/divar3v3282399070.urdf
# ./urdfs/AutoGen/divar3v1635079143.urdf
# ./urdfs/AutoGen/divar3v7117426503.urdf
# ./urdfs/AutoGen/divar3v7141454769.urdf
# ./urdfs/AutoGen/divar3v900263315.urdf
# ./urdfs/AutoGen/divar3v2456512027.urdf
# ./urdfs/AutoGen/divar3v6447785003.urdf
# ./urdfs/AutoGen/divar3v5459655296.urdf
# ./urdfs/AutoGen/divar3v687583492.urdf
# ./urdfs/AutoGen/divar3v7975332915.urdf
# ./urdfs/AutoGen/divar3v4850553613.urdf
# ./urdfs/AutoGen/divar3v2320146140.urdf
# ./urdfs/AutoGen/divar3v3187310331.urdf
# ./urdfs/AutoGen/divar3v4052598591.urdf
# ./urdfs/AutoGen/divar3v2548135498.urdf
# ./urdfs/AutoGen/divar3v4645156997.urdf
# ./urdfs/AutoGen/divar3v7680793230.urdf
# ./urdfs/AutoGen/divar3v7843632783.urdf
# ./urdfs/AutoGen/divar3v1733721400.urdf
# ./urdfs/AutoGen/divar3v5990331329.urdf
# ./urdfs/AutoGen/divar3v5842495582.urdf
# ./urdfs/AutoGen/divar3v9376673165.urdf
# ./urdfs/AutoGen/divar3v4654184185.urdf
# ./urdfs/AutoGen/divar3v4412193731.urdf
# ./urdfs/AutoGen/divar3v3078223231.urdf
# ./urdfs/AutoGen/divar3v4047214372.urdf
# ./urdfs/AutoGen/divar3v2561369510.urdf
# ./urdfs/AutoGen/divar3v4071196312.urdf
# ./urdfs/AutoGen/divar3v7074871985.urdf
# ./urdfs/AutoGen/divar3v6953267388.urdf
# ./urdfs/AutoGen/divar3v2443144748.urdf
# ./urdfs/AutoGen/divar3v6489229325.urdf
# ./urdfs/AutoGen/divar3v6187623051.urdf
# ./urdfs/AutoGen/divar3v5338401800.urdf
# ./urdfs/AutoGen/divar3v2154192505.urdf
# ./urdfs/AutoGen/divar3v7408310649.urdf
# ./urdfs/AutoGen/divar3v4809598530.urdf
# ./urdfs/AutoGen/divar3v3179977038.urdf
# ./urdfs/AutoGen/divar3v9672418005.urdf
# ./urdfs/AutoGen/divar3v823118711.urdf
# ./urdfs/AutoGen/divar3v389483539.urdf
# ./urdfs/AutoGen/divar3v2537492811.urdf
# ./urdfs/AutoGen/divar3v9199364940.urdf
# ./urdfs/AutoGen/divar3v2886938678.urdf
# ./urdfs/AutoGen/divar3v6769414452.urdf
# ./urdfs/AutoGen/divar3v3967085526.urdf
# ./urdfs/AutoGen/divar3v4190636657.urdf
# ./urdfs/AutoGen/divar3v545855245.urdf
# ./urdfs/AutoGen/divar3v6250991433.urdf
# ./urdfs/AutoGen/divar3v1014531391.urdf
# ./urdfs/AutoGen/divar3v3209415478.urdf
# ./urdfs/AutoGen/divar3v9004649965.urdf
# ./urdfs/AutoGen/divar3v9685297432.urdf
# ./urdfs/AutoGen/divar3v6818694927.urdf
# ./urdfs/AutoGen/divar3v9767742736.urdf
# ./urdfs/AutoGen/divar3v1184590544.urdf
# ./urdfs/AutoGen/divar3v8237117430.urdf
# ./urdfs/AutoGen/divar3v7905552714.urdf
# ./urdfs/AutoGen/divar3v3495842783.urdf
# ./urdfs/AutoGen/divar3v1281360348.urdf
# ./urdfs/AutoGen/divar3v8864402578.urdf
# ./urdfs/AutoGen/divar3v2514414689.urdf
# ./urdfs/AutoGen/divar3v1977985595.urdf
# ./urdfs/AutoGen/divar3v386102296.urdf
# ./urdfs/AutoGen/divar3v8202752360.urdf
# ./urdfs/AutoGen/divar3v7624348075.urdf
# ./urdfs/AutoGen/divar3v9674071222.urdf
# ./urdfs/AutoGen/divar3v7456221154.urdf
# ./urdfs/AutoGen/divar3v5968728683.urdf
# ./urdfs/AutoGen/divar3v5693126357.urdf
#
#    Gen:        Fevals:          Best:            dx:            df:         sigma:
#       1              0        1.1e+09    1.10297e+08    1.83301e+10            0.3
# Exit condition -- generations = 3
# CPU times: user 3h 18min 28s, sys: 6min 1s, total: 3h 24min 30s
# Wall time: 3h 12min 42s

# %%
a = archi.get_champions_f()
a2 = sorted(archi.get_champions_f(), key = lambda x: x[0])[0]
best_isl_idx = [(el == a2).all() for el in a].index(True)
x_best = archi.get_champions_x()[best_isl_idx]
f_best = archi.get_champions_f()[best_isl_idx]
print(dv_names)
print("Best relaxed solution, x: {}".format(x_best))
print("Best relaxed solution, f: {}".format(f_best))
# Out:
# ['tau_mu', 'b0', 'Km', 'k_velocity', 'tau_max_m', 'omega_max_m', 'gear_ratio', 'Kp', 'Kd', 'm_m', 'a1', 'lua', 'a23_distr', 'lfa', 'a45_distr', 'a7', 'k1', 'k2', 'k3']
# Best relaxed solution, x: [6.64716401e-03 0.00000000e+00 1.37096253e+00 1.10292265e+01
#  1.44508237e+00 3.02143018e+03 2.50000000e+01 7.35519756e+01
#  1.08684648e+01 7.65727918e-01 2.40561788e-01 1.38711784e-01
#  4.48576885e-01 1.38789589e-01 1.87717979e-01 1.56116788e-01
#  1.69232621e+04 2.28930453e+08 1.68806315e+08]
# Best relaxed solution, f: [1.10000014e+09]

# %%
x_best
# Out:
# array([6.64716401e-03, 0.00000000e+00, 1.37096253e+00, 1.10292265e+01,
#        1.44508237e+00, 3.02143018e+03, 2.50000000e+01, 7.35519756e+01,
#        1.08684648e+01, 7.65727918e-01, 2.40561788e-01, 1.38711784e-01,
#        4.48576885e-01, 1.38789589e-01, 1.87717979e-01, 1.56116788e-01,
#        1.69232621e+04, 2.28930453e+08, 1.68806315e+08])

# %%
# opt_sample = np.array([6.91807585e-03, 5.44435793e-04, 3.28143369e+00, 1.59895149e+01,
#        1.84029964e+00, 2.33200843e+03, 2.35589212e+01, 6.09537226e+01,
#        1.09360919e+01, 1.85929336e-02, 2.20452583e-01, 3.58581821e-01,
#        7.19141155e-01, 4.57393703e-01, 6.06663155e-01, 1.02736512e-01])


# 40, 150, Singular matrix error
# opt_sample = np.array([7.96143308e-03, 3.36910845e-03, 3.94727839e+00, 4.74012394e+01,
#        2.82192349e+00, 2.08077837e+03, 2.08368058e+01, 6.01099903e+01,
#        1.88410482e+01, 3.88514060e-01, 2.94486612e-01, 3.66461430e-01,
#        3.28397450e-01, 3.76634459e-01, 7.23319206e-01, 1.34282196e-01,
#        1.08095971e+04, 2.00340487e+08, 3.53848956e+08])

# 3, 300 
# opt_sample = np.array([6.64716401e-03, 0.00000000e+00, 1.37096253e+00, 1.10292265e+01,
#        1.44508237e+00, 3.02143018e+03, 2.50000000e+01, 7.35519756e+01,
#        1.08684648e+01, 7.65727918e-01, 2.40561788e-01, 1.38711784e-01,
#        4.48576885e-01, 1.38789589e-01, 1.87717979e-01, 1.56116788e-01,
#        1.69232621e+04, 2.28930453e+08, 1.68806315e+08])

# 30, 150, error control
# opt_sample = np.array([8.56463949e-03, 2.41717386e-04, 2.81786362e+00, 1.32940246e+01,
#        2.41273378e+00, 3.54583616e+03, 2.49193397e+01, 7.67284037e+01,
#        1.32017787e+01, 1.63787830e+00, 1.73908215e-01, 4.05462599e-01,
#        8.25450860e-01, 4.14593783e-01, 8.55725276e-01, 1.47186740e-01,
#        1.64983127e+04, 1.82610214e+08, 1.51677526e+08])

# 10, 750, error control
# opt_sample = np.array([9.53879251e-03, 2.69658578e-03, 4.76413795e+00, 3.42204860e+01,
#        2.20700750e+00, 1.19888250e+03, 1.65240873e+01, 9.04692417e+01,
#        2.41572130e+01, 9.08769779e-01, 2.66998236e-01, 2.76143568e-01,
#        9.16581664e-01, 4.63879861e-01, 2.74830855e-01, 1.46614205e-01,
#        3.45667282e+03, 1.03240626e+08, 2.46728269e+06])

# opt_sample = np.array([0.0057857849071482875, 0.0, 1.6175622072824287, 30.0, 0.3919489602398743, 3140.511961626532,
#   25.0, 20.60346310039638, 10.0, 0.20668422373398593, 0.1, 0.39753344825851633, 0.6696554213945205, 0.5,
#   0.95, 0.172556429902661, 100.0, 379000000.0, 22491618.530260332])


# 10, 750, no error, 18hr wall time
opt_sample = np.array([7.59643468e-03, 0.00000000e+00, 3.85945462e+00, 1.61568531e+01,
       1.18077249e+00, 3.20282925e+03, 2.13285263e+01, 9.06534252e+01,
       1.72003275e+01, 1.50344975e+00, 1.00000000e-01, 1.05274237e-01,
       3.68761758e-01, 1.00000000e-01, 5.00000000e-02, 1.44383000e-01,
       1.24016242e+04, 2.78090215e+08, 3.38890725e+07])


results = compute_QoI(pre_val, dv_names, opt_sample, case, clf, fit_params, run_sim = True)
print(results)
K_w = np.diag([1e3,1,1,1,100,5,5,0])
# Quadratic objective meta function with weights
fitness_val = np.matmul(K_w, results).dot(results)
print(fitness_val)
# ([workspace, feasibility, deflection, payload, 
#   ts, total_friction_loss, total_joule_loss, final_error])
# Out:
# ./urdfs/AutoGen/divar3v5223047923.urdf
# Max realised torque 348.4601105297552
# [1.82005547e-11 1.00000000e+04 1.00000000e+04 0.00000000e+00
#  5.00000000e+00 2.75697593e+01 2.87010959e+00 4.75209429e+00]
# 200006341.64579242

# %%
def gripper_forward_kinematics_example():
    urdf_path = './urdfs/AutoGen/divar3v835978448.urdf'
#     urdf_path = './urdfs/divar3v7757625049.urdf'
    builder = DiagramBuilder()
    plant, scene_graph = AddMultibodyPlantSceneGraph(builder, time_step=1e-4)
    model = Parser(plant, scene_graph).AddModelFromFile(urdf_path, 'diva_robot')
    # Transform for the robot location
    X_R = RigidTransform(RotationMatrix.MakeYRotation(-np.pi/2), np.array([-0.1, 0.5, 1.3]))
    plant.WeldFrames(plant.world_frame(), plant.get_body(plant.GetBodyIndices(model)[0]).body_frame(), X_R)
    # Spawn table|
    table = Parser(plant, scene_graph).AddModelFromFile('./urdfs/table/extra_heavy_duty_table_modified.sdf','table')
    # Spawn spherical work piece
    sphere = Parser(plant, scene_graph).AddModelFromFile('./urdfs/helper/sphere.urdf','sphere')
    X_R = RigidTransform(RotationMatrix(RollPitchYaw([0, 0, 0])), np.array([0, 0, 0.736]))
    plant.WeldFrames(plant.world_frame(), plant.get_body(plant.GetBodyIndices(sphere)[0]).body_frame(), X_R)

    plant.Finalize()
    
    end_frame = "eef"
    
    # Draw the frames
    for body_name in ["base_link", end_frame]:
        AddMultibodyTriad(plant.GetFrameByName(body_name, model), scene_graph)

    meshcat.Delete()
    meshcat.DeleteAddedControls()

    visualizer = MeshcatVisualizerCpp.AddToBuilder(builder, scene_graph, meshcat)

    diagram = builder.Build()
    context = diagram.CreateDefaultContext()
    
    gripper = plant.GetBodyByName(end_frame)
    def pose_callback(context):
        pose = plant.EvalBodyPoseInWorld(context, gripper)   ## This is the important line
        print(pose.translation())
        clear_output(wait=True)
        print("gripper position (m): " + np.array2string(
            pose.translation(), formatter={
                'float': lambda x: "{:3.2f}".format(x)}))
        print("gripper roll-pitch-yaw (rad):" + np.array2string(
            RollPitchYaw(pose.rotation()).vector(),
                         formatter={'float': lambda x: "{:3.2f}".format(x)}))
        print("pose rotation: ", pose.rotation())
    sliders = MeshcatJointSlidersThatPublish(meshcat, plant, visualizer, context)
    # sliders.Run()
    sliders.Run(pose_callback)

gripper_forward_kinematics_example()
# Out:
# gripper position (m): [-0.46 -0.31 1.37]
# gripper roll-pitch-yaw (rad):[1.28 0.20 1.29]
# pose rotation:  RotationMatrix([
#   [0.2710414349693712, -0.22182774469285746, 0.9366584181088773],
#   [0.9413029638889925, 0.26449034564071244, -0.20974648325217368],
#   [-0.20120951941581205, 0.9385293329179099, 0.2804949563702012],
# ])

# %%
# carti = np.array([-0.53, 0.13, 0.81])
# orii = np.array([-3.14, 0, 1.35])
# qi = np.array([-0.64224017, -0.35515685, -1.01065151,  1.69796737, -0.2877014 ,0.87728685, -0.03373386])

# cartf = np.array([-0.23, 0.24, 1.03])
# orii = np.array([3.14, 0, 2.5])
# qi = np.array([0.27, 0, -2.4, 2, -0.5, 0.38, 0.64])
